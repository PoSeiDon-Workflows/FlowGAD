# %%
graphs = []
classes = {"normal": 0}
counter = 1
for d in os.listdir("data"):
    d = d.split("_")[0]
    if d in classes: continue
    classes[d] = counter
    counter += 1
    
counter = 0
edge_index = []
lookup = {}
print("1000genome")
with open("adjacency_list_dags/1000genome.json", "r") as f:
    adjacency_list = json.load(f)
for l in adjacency_list:
    lookup[l] = counter
    counter+=1
for l in adjacency_list:
    for e in adjacency_list[l]:
        edge_index.append([lookup[l], lookup[e]])
import math
for d in os.listdir("data"):
    print(d)
    for f in glob.glob(os.path.join("data", d, "1000genome*")):
        graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
        features = pd.read_csv(f, index_col=[0])
        features= features.replace('', -1, regex=True)
        # time_list
        for l in lookup:
            if l.startswith("create_dir_") or l.startswith("cleanup_"):
                new_l = l.split("-")[0]
            else:
                new_l = l
            job_features = features[features.index.str.startswith(new_l)][['type', 'ready',
                                   'submit', 'execute_start', 'execute_end', 'post_script_start',
                                   'post_script_end', 'wms_delay', 'pre_script_delay', 'queue_delay',
                                   'runtime', 'post_script_delay', 'stage_in_delay', 'stage_out_delay']].values.tolist()[0]
            
            if job_features[0]=='auxiliary':
                job_features[0]= 0
            if job_features[0]=='compute':
                job_features[0]= 1
            if job_features[0]=='transfer':
                job_features[0]= 2
            
            # print(job_features)
            job_features = [-1 if x != x else x for x in job_features]
            graph['x'].insert(lookup[l], job_features)
        t_list=[]
        for i in range(len(graph['x'])):
            t_list.append(graph['x'][i][1])
        minim= min(t_list)
        for i in range(len(graph['x'])):
            lim = graph['x'][i][1:7]
            lim=[ v-minim for v in lim]
            graph['x'][i][1:7]= lim
        graphs.append(graph)
        

        
print("casa_nowcast_clustering_16")
counter = 0
edge_index = []
lookup = {}
with open("adjacency_list_dags/casa_nowcast_clustering_16.json", "r") as f:
    adjacency_list = json.load(f)
for l in adjacency_list:
    lookup[l] = counter
    counter+=1
for l in adjacency_list:
    for e in adjacency_list[l]:
        edge_index.append([lookup[l], lookup[e]])               
for d in os.listdir("data"):
    print(d)
    for f in glob.glob(os.path.join("data", d, "nowcast-clustering-16*")):
        graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
        features = pd.read_csv(f, index_col=[0])
        features= features.replace('', -1, regex=True)
        # time_list
        for l in lookup:
            if l.startswith("create_dir_") or l.startswith("cleanup_"):
                new_l = l.split("-")[0]
            else:
                new_l = l
            job_features = features[features.index.str.startswith(new_l)][['type', 'ready',
                                   'submit', 'execute_start', 'execute_end', 'post_script_start',
                                   'post_script_end', 'wms_delay', 'pre_script_delay', 'queue_delay',
                                   'runtime', 'post_script_delay', 'stage_in_delay', 'stage_out_delay']].values.tolist()[0]
            # print(job_features)
            if job_features[0]=='auxiliary':
                job_features[0]= 0
            if job_features[0]=='compute':
                job_features[0]= 1
            if job_features[0]=='transfer':
                job_features[0]= 2
                #             print(job_features)
            job_features = [-1 if x != x else x for x in job_features]
            graph['x'].insert(lookup[l], job_features)
        t_list=[]
        for i in range(len(graph['x'])):
            t_list.append(graph['x'][i][1])
        minim= min(t_list)
        for i in range(len(graph['x'])):
            lim = graph['x'][i][1:7]
            lim=[ v-minim for v in lim]
            graph['x'][i][1:7]= lim            
        graphs.append(graph)
        break
        
print("casa_nowcast_clustering_8")
counter = 0
edge_index = []
lookup = {}
with open("adjacency_list_dags/casa_nowcast_clustering_8.json", "r") as f:
    adjacency_list = json.load(f)
for l in adjacency_list:
    lookup[l] = counter
    counter+=1
for l in adjacency_list:
    for e in adjacency_list[l]:
        edge_index.append([lookup[l], lookup[e]])     
for d in os.listdir("data"):
    print(d)
    for f in glob.glob(os.path.join("data", d, "nowcast-clustering-8*")):
        graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
        features = pd.read_csv(f, index_col=[0])
        features= features.replace('', -1, regex=True)
        # time_list
        for l in lookup:
            if l.startswith("create_dir_") or l.startswith("cleanup_"):
                new_l = l.split("-")[0]
            else:
                new_l = l
            job_features = features[features.index.str.startswith(new_l)][['type', 'ready',
                                   'submit', 'execute_start', 'execute_end', 'post_script_start',
                                   'post_script_end', 'wms_delay', 'pre_script_delay', 'queue_delay',
                                   'runtime', 'post_script_delay', 'stage_in_delay', 'stage_out_delay']].values.tolist()[0]
            if job_features[0]=='auxiliary':
                job_features[0]= 0
            if job_features[0]=='compute':
                job_features[0]= 1
            if job_features[0]=='transfer':
                job_features[0]= 2
                #             print(job_features)
            job_features = [-1 if x != x else x for x in job_features]
            graph['x'].insert(lookup[l], job_features)
        t_list=[]
        for i in range(len(graph['x'])):
            t_list.append(graph['x'][i][1])
        minim= min(t_list)
        for i in range(len(graph['x'])):
            lim = graph['x'][i][1:7]
            lim=[ v-minim for v in lim]
            graph['x'][i][1:7]= lim
        graphs.append(graph)
        
print("casa_wind_clustering")
counter = 0
edge_index = []
lookup = {}
with open("adjacency_list_dags/casa_wind_clustering.json", "r") as f:
    adjacency_list = json.load(f)
for l in adjacency_list:
    lookup[l] = counter
    counter+=1
for l in adjacency_list:
    for e in adjacency_list[l]:
        edge_index.append([lookup[l], lookup[e]])   
for d in os.listdir("data"):
    print(d)
    for f in glob.glob(os.path.join("data", d, "wind-clustering-casa*")):
        graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
        features = pd.read_csv(f, index_col=[0])
        features= features.replace('', -1, regex=True)
        # time_list
        for l in lookup:
            if l.startswith("create_dir_") or l.startswith("cleanup_"):
                new_l = l.split("-")[0]
            else:
                new_l = l
            job_features = features[features.index.str.startswith(new_l)][['type', 'ready',
                                   'submit', 'execute_start', 'execute_end', 'post_script_start',
                                   'post_script_end', 'wms_delay', 'pre_script_delay', 'queue_delay',
                                   'runtime', 'post_script_delay', 'stage_in_delay', 'stage_out_delay']].values.tolist()[0]
            if job_features[0]=='auxiliary':
                job_features[0]= 0
            if job_features[0]=='compute':
                job_features[0]= 1
            if job_features[0]=='transfer':
                job_features[0]= 2
                #             print(job_features)
            job_features = [-1 if x != x else x for x in job_features]
            graph['x'].insert(lookup[l], job_features)
        t_list=[]
        for i in range(len(graph['x'])):
            t_list.append(graph['x'][i][1])
        minim= min(t_list)
        for i in range(len(graph['x'])):
            lim = graph['x'][i][1:7]
            lim=[ v-minim for v in lim]
            graph['x'][i][1:7]= lim
        graphs.append(graph)

# %%
print("casa_wind_no_clustering")
counter = 0
edge_index = []
lookup = {}
with open("adjacency_list_dags/casa_wind_no_clustering.json", "r") as f:
    adjacency_list = json.load(f)
for l in adjacency_list:
    lookup[l] = counter
    counter+=1
for l in adjacency_list:
    for e in adjacency_list[l]:
        edge_index.append([lookup[l], lookup[e]])     
for d in os.listdir("data"):
    print(d)
    for f in glob.glob(os.path.join("data", d, "wind-noclustering-casa*")):
        graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
        features = pd.read_csv(f, index_col=[0])
        features= features.replace('', -1, regex=True)
        # time_list
        for l in lookup:
            if l.startswith("create_dir_") or l.startswith("cleanup_"):
                new_l = l.split("-")[0]
            else:
                new_l = l
            # print(len(features[features.index.str.startswith(new_l)]) )
            #type,ready,pre_script_start,pre_script_end,submit,execute_start,
            #execute_end,post_script_start,post_script_end,wms_delay,pre_script_delay,
            #queue_delay,runtime,post_script_delay,stage_in_delay,stage_out_delay
            if len(features[features.index.str.startswith(new_l)])<1:
                print(new_l)
                continue
                
            job_features = features[features.index.str.startswith(new_l)][['type', 'ready',
                                   'submit', 'execute_start', 'execute_end', 'post_script_start',
                                   'post_script_end', 'wms_delay', 'pre_script_delay', 'queue_delay',
                                   'runtime', 'post_script_delay', 'stage_in_delay', 'stage_out_delay']].values.tolist()[0]
            if job_features[0]=='auxiliary':
                job_features[0]= 0
            if job_features[0]=='compute':
                job_features[0]= 1
            if job_features[0]=='transfer':
                job_features[0]= 2
                #             print(job_features)
            job_features = [-1 if x != x else x for x in job_features]
            graph['x'].insert(lookup[l], job_features)
        t_list=[]
        for i in range(len(graph['x'])):
            t_list.append(graph['x'][i][1])
        minim= min(t_list)
        for i in range(len(graph['x'])):
            lim = graph['x'][i][1:7]
            lim=[ v-minim for v in lim]
            graph['x'][i][1:7]= lim
        # graphs.append(graph)

# %%
## Dumped into the pickle file.
import pickle
with open('graph_all_.pkl','wb') as f:
    pickle.dump(graphs, f)

# %%
import json
import glob
import os
import pandas as pd
import numpy as np
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Import the file.
import pickle
with open('graph_all_.pkl','rb') as f:
    graphs= pickle.load(f)

# %%
import numpy as np
y_list = []
for gr in graphs:
    y_list.append(gr['y'])
print(min(y_list))
print(max(y_list))
print(np.unique(np.array(y_list), return_counts=True))
# Out:
# 0
# 3
# (array([0, 1, 2, 3]), array([ 741,  852, 1301,  855]))

# %%
import torch
from torch_geometric.data import Data
datasets=[]
import numpy
for element in graphs:
    gx = torch.tensor(numpy.array(element['x']) ) 
    
    ge =torch.tensor(numpy.array(element['edge_index']) ).T
    gy =torch.tensor(numpy.array(element['y']).reshape([-1]))
    print(gx.shape, ge.shape, gy.shape)
    # print(gy)
    v_min, v_max = gx.min(), gx.max()
    new_min, new_max = -1, 1
    gx = (gx - v_min)/(v_max - v_min)*(new_max - new_min) + new_min
    # print(gx.min(), gx.max())
    datasets.append( Data(x=gx, edge_index=ge, y=gy) )
# Out:
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# ...
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])
# torch.Size([7, 14]) torch.Size([2, 8]) torch.Size([1])

# %%
import torch
from torch_geometric.datasets import TUDataset

dataset = datasets

# # print()
# # print(f'Dataset: {dataset}:')
# print('====================')
# print(f'Number of graphs: {len(dataset)}')
# # print(f'Number of features: {dataset.num_features}')
# # print(f'Number of classes: {dataset.num_classes}')
# data = dataset[0]  # Get the first graph object.
# print()
# print(data)
# print('=============================================================')
# # Gather some statistics about the first graph.
# print(f'Number of nodes: {data.num_nodes}')
# print(f'Number of edges: {data.num_edges}')
# print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
# print(f'Has isolated nodes: {data.has_isolated_nodes()}')
# print(f'Has self-loops: {data.has_self_loops()}')
# print(f'Is undirected: {data.is_undirected()}')

# %%
torch.manual_seed(12345)
import random
random.seed(12345)
random.shuffle(datasets)
train_dataset = datasets[:3000]
test_dataset = datasets[3000:]

print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')
# Out:
# Number of training graphs: 3000
# Number of test graphs: 749

# %%
from torch_geometric.loader import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1742, 14], edge_index=[2, 3583], y=[64], batch=[1742], ptr=[65])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1310, 14], edge_index=[2, 2530], y=[64], batch=[1310], ptr=[65])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1508, 14], edge_index=[2, 3031], y=[64], batch=[1508], ptr=[65])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1792, 14], edge_index=[2, 3704], y=[64], batch=[1792], ptr=[65])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1730, 14], edge_index=[2, 3538], y=[64], batch=[1730], ptr=[65])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1806, 14], edge_index=[2, 3753], y=[64], batch=[1806], ptr=[65])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1980, 14], edge_index=[2, 4164], y=[64], batch=[1980], ptr=[65])
#
# Step 8:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1382, 14], edge_index=[2, 2716], y=[64], batch=[1382], ptr=[65])
#
# Step 9:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1588, 14], edge_index=[2, 3233], y=[64], batch=[1588], ptr=[65])
#
# Step 10:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1464, 14], edge_index=[2, 2922], y=[64], batch=[1464], ptr=[65])
#
# Step 11:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1386, 14], edge_index=[2, 2724], y=[64], batch=[1386], ptr=[65])
#
# Step 12:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1806, 14], edge_index=[2, 3753], y=[64], batch=[1806], ptr=[65])
#
# Step 13:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1840, 14], edge_index=[2, 3842], y=[64], batch=[1840], ptr=[65])
#
# Step 14:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1604, 14], edge_index=[2, 3244], y=[64], batch=[1604], ptr=[65])
#
# Step 15:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1506, 14], edge_index=[2, 3027], y=[64], batch=[1506], ptr=[65])
#
# Step 16:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1968, 14], edge_index=[2, 4140], y=[64], batch=[1968], ptr=[65])
#
# Step 17:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1918, 14], edge_index=[2, 4019], y=[64], batch=[1918], ptr=[65])
#
# Step 18:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1628, 14], edge_index=[2, 3292], y=[64], batch=[1628], ptr=[65])
#
# Step 19:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1624, 14], edge_index=[2, 3305], y=[64], batch=[1624], ptr=[65])
#
# Step 20:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1724, 14], edge_index=[2, 3547], y=[64], batch=[1724], ptr=[65])
#
# Step 21:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1844, 14], edge_index=[2, 3850], y=[64], batch=[1844], ptr=[65])
#
# Step 22:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1304, 14], edge_index=[2, 2518], y=[64], batch=[1304], ptr=[65])
#
# Step 23:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1692, 14], edge_index=[2, 3483], y=[64], batch=[1692], ptr=[65])
#
# Step 24:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1786, 14], edge_index=[2, 3692], y=[64], batch=[1786], ptr=[65])
#
# Step 25:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1788, 14], edge_index=[2, 3717], y=[64], batch=[1788], ptr=[65])
#
# Step 26:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1354, 14], edge_index=[2, 2639], y=[64], batch=[1354], ptr=[65])
#
# Step 27:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1594, 14], edge_index=[2, 3245], y=[64], batch=[1594], ptr=[65])
#
# Step 28:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1850, 14], edge_index=[2, 3862], y=[64], batch=[1850], ptr=[65])
#
# Step 29:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1432, 14], edge_index=[2, 2837], y=[64], batch=[1432], ptr=[65])
#
# Step 30:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1670, 14], edge_index=[2, 3418], y=[64], batch=[1670], ptr=[65])
#
# Step 31:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1768, 14], edge_index=[2, 3656], y=[64], batch=[1768], ptr=[65])
#
# Step 32:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1692, 14], edge_index=[2, 3462], y=[64], batch=[1692], ptr=[65])
#
# Step 33:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1338, 14], edge_index=[2, 2607], y=[64], batch=[1338], ptr=[65])
#
# Step 34:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1466, 14], edge_index=[2, 2905], y=[64], batch=[1466], ptr=[65])
#
# Step 35:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1536, 14], edge_index=[2, 3087], y=[64], batch=[1536], ptr=[65])
#
# Step 36:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1486, 14], edge_index=[2, 2966], y=[64], batch=[1486], ptr=[65])
#
# Step 37:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1500, 14], edge_index=[2, 3015], y=[64], batch=[1500], ptr=[65])
#
# Step 38:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1668, 14], edge_index=[2, 3414], y=[64], batch=[1668], ptr=[65])
#
# Step 39:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1944, 14], edge_index=[2, 4092], y=[64], batch=[1944], ptr=[65])
#
# Step 40:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1660, 14], edge_index=[2, 3377], y=[64], batch=[1660], ptr=[65])
#
# Step 41:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1656, 14], edge_index=[2, 3390], y=[64], batch=[1656], ptr=[65])
#
# Step 42:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1726, 14], edge_index=[2, 3572], y=[64], batch=[1726], ptr=[65])
#
# Step 43:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1430, 14], edge_index=[2, 2833], y=[64], batch=[1430], ptr=[65])
#
# Step 44:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1806, 14], edge_index=[2, 3753], y=[64], batch=[1806], ptr=[65])
#
# Step 45:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1620, 14], edge_index=[2, 3297], y=[64], batch=[1620], ptr=[65])
#
# Step 46:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1780, 14], edge_index=[2, 3680], y=[64], batch=[1780], ptr=[65])
#
# Step 47:
# =======
# Number of graphs in the current batch: 56
# DataBatch(x=[1528, 14], edge_index=[2, 3161], y=[56], batch=[1528], ptr=[57])

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, ChebConv, SAGEConv
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = SAGEConv(14, hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 4)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)
        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]
        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        return x

model = GCN(hidden_channels=64).to(device)
print(model)
# Out:
# GCN(
#   (conv1): SAGEConv(14, 64)
#   (conv2): SAGEConv(64, 64)
#   (conv3): SAGEConv(64, 64)
#   (lin): Linear(in_features=64, out_features=4, bias=True)
# )

# %%
model = GCN(hidden_channels=64).float().to(device)

criterion = torch.nn.CrossEntropyLoss()
# from IPython.display import Javascript
# display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))     
def train():
    model.train()
    for data in train_loader:  # Iterate in batches over the training dataset.
        out = model(data.x.float().to(device), data.edge_index.to(device), data.batch.to(device))  # Perform a single forward pass.
        loss = criterion(out, data.y.to(device) )  # Compute the loss.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        optimizer.zero_grad()  # Clear gradients.

def test(loader):
    model.eval()
    correct = 0
    for data in loader:  # Iterate in batches over the training/test dataset.
        out = model(data.x.float().to(device), data.edge_index.to(device), data.batch.to(device))  
        pred = out.argmax(dim=1).detach().cpu()  # Use the class with highest probability.
        correct += int((pred == data.y).sum())  # Check against ground-truth labels.
    return correct / len(loader.dataset)  # Derive ratio of correct predictions.

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
import torch.optim.lr_scheduler as lrs
scheduler = lrs.ExponentialLR(optimizer, gamma=0.9)
for epoch in range(1, 10000):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    if epoch%50==0:
        scheduler.step()
        print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# Epoch: 050, Train Acc: 0.7323, Test Acc: 0.7063
# Epoch: 100, Train Acc: 0.7380, Test Acc: 0.7263
# Epoch: 150, Train Acc: 0.7067, Test Acc: 0.6809
# Epoch: 200, Train Acc: 0.7357, Test Acc: 0.7023
# Epoch: 250, Train Acc: 0.7240, Test Acc: 0.6876
# Epoch: 300, Train Acc: 0.7133, Test Acc: 0.7036
# Epoch: 350, Train Acc: 0.7423, Test Acc: 0.7250
# Epoch: 400, Train Acc: 0.7540, Test Acc: 0.7303
# Epoch: 450, Train Acc: 0.7250, Test Acc: 0.7023
# Epoch: 500, Train Acc: 0.7503, Test Acc: 0.7236
# Epoch: 550, Train Acc: 0.7530, Test Acc: 0.7089
# Epoch: 600, Train Acc: 0.7690, Test Acc: 0.7477
# Epoch: 650, Train Acc: 0.7713, Test Acc: 0.7477
# Epoch: 700, Train Acc: 0.7740, Test Acc: 0.7597
# Epoch: 750, Train Acc: 0.7593, Test Acc: 0.7423
# Epoch: 800, Train Acc: 0.7657, Test Acc: 0.7583
# Epoch: 850, Train Acc: 0.7773, Test Acc: 0.7610
# Epoch: 900, Train Acc: 0.7820, Test Acc: 0.7543
# Epoch: 950, Train Acc: 0.7717, Test Acc: 0.7503
# Epoch: 1000, Train Acc: 0.7783, Test Acc: 0.7517
# Epoch: 1050, Train Acc: 0.7687, Test Acc: 0.7370
# Epoch: 1100, Train Acc: 0.7740, Test Acc: 0.7463
# Epoch: 1150, Train Acc: 0.7690, Test Acc: 0.7530
# Epoch: 1200, Train Acc: 0.7830, Test Acc: 0.7610
# Epoch: 1250, Train Acc: 0.7767, Test Acc: 0.7437
# Epoch: 1300, Train Acc: 0.7833, Test Acc: 0.7583
# Epoch: 1350, Train Acc: 0.7777, Test Acc: 0.7423
# Epoch: 1400, Train Acc: 0.7773, Test Acc: 0.7423
# Epoch: 1450, Train Acc: 0.7823, Test Acc: 0.7597
# Epoch: 1500, Train Acc: 0.7870, Test Acc: 0.7597
# Epoch: 1550, Train Acc: 0.7750, Test Acc: 0.7410
# Epoch: 1600, Train Acc: 0.7850, Test Acc: 0.7517
# Epoch: 1650, Train Acc: 0.7843, Test Acc: 0.7570
# Epoch: 1700, Train Acc: 0.7893, Test Acc: 0.7597
# Epoch: 1750, Train Acc: 0.7747, Test Acc: 0.7583
# Epoch: 1800, Train Acc: 0.7763, Test Acc: 0.7370
# Epoch: 1850, Train Acc: 0.7847, Test Acc: 0.7597
# Epoch: 1900, Train Acc: 0.7777, Test Acc: 0.7437
# Epoch: 1950, Train Acc: 0.7867, Test Acc: 0.7543
# Epoch: 2000, Train Acc: 0.7870, Test Acc: 0.7543
# Epoch: 2050, Train Acc: 0.7843, Test Acc: 0.7623
# Epoch: 2100, Train Acc: 0.7847, Test Acc: 0.7557
# Epoch: 2150, Train Acc: 0.7813, Test Acc: 0.7490
# Epoch: 2200, Train Acc: 0.7873, Test Acc: 0.7623
# Epoch: 2250, Train Acc: 0.7857, Test Acc: 0.7570
# Epoch: 2300, Train Acc: 0.7870, Test Acc: 0.7583
# Epoch: 2350, Train Acc: 0.7863, Test Acc: 0.7557
# Epoch: 2400, Train Acc: 0.7840, Test Acc: 0.7583
# Epoch: 2450, Train Acc: 0.7853, Test Acc: 0.7557
# Epoch: 2500, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 2550, Train Acc: 0.7863, Test Acc: 0.7610
# Epoch: 2600, Train Acc: 0.7860, Test Acc: 0.7570
# Epoch: 2650, Train Acc: 0.7877, Test Acc: 0.7583
# Epoch: 2700, Train Acc: 0.7860, Test Acc: 0.7570
# Epoch: 2750, Train Acc: 0.7857, Test Acc: 0.7543
# Epoch: 2800, Train Acc: 0.7860, Test Acc: 0.7570
# Epoch: 2850, Train Acc: 0.7847, Test Acc: 0.7570
# Epoch: 2900, Train Acc: 0.7883, Test Acc: 0.7570
# Epoch: 2950, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 3000, Train Acc: 0.7847, Test Acc: 0.7557
# Epoch: 3050, Train Acc: 0.7833, Test Acc: 0.7557
# Epoch: 3100, Train Acc: 0.7843, Test Acc: 0.7570
# Epoch: 3150, Train Acc: 0.7860, Test Acc: 0.7570
# Epoch: 3200, Train Acc: 0.7867, Test Acc: 0.7570
# Epoch: 3250, Train Acc: 0.7863, Test Acc: 0.7557
# Epoch: 3300, Train Acc: 0.7850, Test Acc: 0.7557
# Epoch: 3350, Train Acc: 0.7870, Test Acc: 0.7583
# Epoch: 3400, Train Acc: 0.7860, Test Acc: 0.7557
# Epoch: 3450, Train Acc: 0.7850, Test Acc: 0.7557
# Epoch: 3500, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 3550, Train Acc: 0.7847, Test Acc: 0.7557
# Epoch: 3600, Train Acc: 0.7847, Test Acc: 0.7557
# Epoch: 3650, Train Acc: 0.7860, Test Acc: 0.7570
# Epoch: 3700, Train Acc: 0.7853, Test Acc: 0.7570
# Epoch: 3750, Train Acc: 0.7850, Test Acc: 0.7583
# Epoch: 3800, Train Acc: 0.7847, Test Acc: 0.7570
# Epoch: 3850, Train Acc: 0.7847, Test Acc: 0.7557
# Epoch: 3900, Train Acc: 0.7850, Test Acc: 0.7583
# Epoch: 3950, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 4000, Train Acc: 0.7847, Test Acc: 0.7570
# Epoch: 4050, Train Acc: 0.7850, Test Acc: 0.7557
# Epoch: 4100, Train Acc: 0.7863, Test Acc: 0.7557
# Epoch: 4150, Train Acc: 0.7860, Test Acc: 0.7557
# Epoch: 4200, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 4250, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 4300, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 4350, Train Acc: 0.7847, Test Acc: 0.7570
# Epoch: 4400, Train Acc: 0.7847, Test Acc: 0.7570
# Epoch: 4450, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 4500, Train Acc: 0.7847, Test Acc: 0.7570
# Epoch: 4550, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 4600, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 4650, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 4700, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 4750, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 4800, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 4850, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 4900, Train Acc: 0.7847, Test Acc: 0.7570
# Epoch: 4950, Train Acc: 0.7847, Test Acc: 0.7570
# Epoch: 5000, Train Acc: 0.7850, Test Acc: 0.7557
# Epoch: 5050, Train Acc: 0.7850, Test Acc: 0.7557
# Epoch: 5100, Train Acc: 0.7850, Test Acc: 0.7557
# Epoch: 5150, Train Acc: 0.7850, Test Acc: 0.7557
# Epoch: 5200, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 5250, Train Acc: 0.7847, Test Acc: 0.7557
# Epoch: 5300, Train Acc: 0.7850, Test Acc: 0.7557
# Epoch: 5350, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 5400, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 5450, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 5500, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 5550, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 5600, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 5650, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 5700, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 5750, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 5800, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 5850, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 5900, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 5950, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6000, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6050, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6100, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6150, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6200, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6250, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6300, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6350, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6400, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6450, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6500, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6550, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6600, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6650, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6700, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6750, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6800, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6850, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6900, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 6950, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7000, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7050, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7100, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7150, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7200, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7250, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7300, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7350, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7400, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7450, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7500, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7550, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7600, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7650, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7700, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7750, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7800, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7850, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7900, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 7950, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8000, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8050, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8100, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8150, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8200, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8250, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8300, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8350, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8400, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8450, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8500, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8550, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8600, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8650, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8700, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8750, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8800, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8850, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8900, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 8950, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9000, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9050, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9100, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9150, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9200, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9250, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9300, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9350, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9400, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9450, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9500, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9550, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9600, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9650, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9700, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9750, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9800, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9850, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9900, Train Acc: 0.7850, Test Acc: 0.7570
# Epoch: 9950, Train Acc: 0.7850, Test Acc: 0.7570
