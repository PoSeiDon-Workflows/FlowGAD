# %%
import json
import glob
import os
import pandas as pd
import numpy as np

graphs = []
classes = {"normal": 0}
counter = 1
for d in os.listdir("data"):
    d = d.split("_")[0]
    if d in classes: continue
    classes[d] = counter
    counter += 1
    
counter = 0
edge_index = []
lookup = {}

# %%
print("1000genome")
with open("adjacency_list_dags/1000genome.json", "r") as f:
    adjacency_list = json.load(f)
for l in adjacency_list:
    lookup[l] = counter
    counter+=1
for l in adjacency_list:
    for e in adjacency_list[l]:
        edge_index.append([lookup[l], lookup[e]])
import math
for d in os.listdir("data"):
    print(d)
    for f in glob.glob(os.path.join("data", d, "1000genome*")):
        graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
        features = pd.read_csv(f, index_col=[0])
        features= features.replace('', -1, regex=True)
        # time_list
        for l in lookup:
            if l.startswith("create_dir_") or l.startswith("cleanup_"):
                new_l = l.split("-")[0]
            else:
                new_l = l
            job_features = features[features.index.str.startswith(new_l)][['type', 'ready',
                                   'submit', 'execute_start', 'execute_end', 'post_script_start',
                                   'post_script_end', 'wms_delay', 'pre_script_delay', 'queue_delay',
                                   'runtime', 'post_script_delay', 'stage_in_delay', 'stage_out_delay']].values.tolist()[0]
            
            if job_features[0]=='auxiliary':
                job_features[0]= 0
            if job_features[0]=='compute':
                job_features[0]= 1
            if job_features[0]=='transfer':
                job_features[0]= 2
            
            # print(job_features)
            job_features = [-1 if x != x else x for x in job_features]
            graph['x'].insert(lookup[l], job_features)
        t_list=[]
        for i in range(len(graph['x'])):
            t_list.append(graph['x'][i][1])
        minim= min(t_list)
        for i in range(len(graph['x'])):
            lim = graph['x'][i][1:7]
            lim=[ v-minim for v in lim]
            graph['x'][i][1:7]= lim
        graphs.append(graph)
# Out:
# 1000genome
# cpu_2
# cpu_3
# hdd_100
# hdd_50
# hdd_60
# hdd_70
# hdd_80
# hdd_90
# loss_0.1
# loss_0.5
# loss_1
# loss_3
# loss_5
# normal

# %%
print("casa_nowcast_clustering_16")
counter = 0
edge_index = []
lookup = {}
with open("adjacency_list_dags/casa_nowcast_clustering_16.json", "r") as f:
    adjacency_list = json.load(f)
for l in adjacency_list:
    lookup[l] = counter
    counter+=1
for l in adjacency_list:
    for e in adjacency_list[l]:
        edge_index.append([lookup[l], lookup[e]])               
for d in os.listdir("data"):
    print(d)
    for f in glob.glob(os.path.join("data", d, "nowcast-clustering-16*")):
        graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
        features = pd.read_csv(f, index_col=[0])
        features= features.replace('', -1, regex=True)
        # time_list
        for l in lookup:
            if l.startswith("create_dir_") or l.startswith("cleanup_"):
                new_l = l.split("-")[0]
            else:
                new_l = l
            job_features = features[features.index.str.startswith(new_l)][['type', 'ready',
                                   'submit', 'execute_start', 'execute_end', 'post_script_start',
                                   'post_script_end', 'wms_delay', 'pre_script_delay', 'queue_delay',
                                   'runtime', 'post_script_delay', 'stage_in_delay', 'stage_out_delay']].values.tolist()[0]
            # print(job_features)
            if job_features[0]=='auxiliary':
                job_features[0]= 0
            if job_features[0]=='compute':
                job_features[0]= 1
            if job_features[0]=='transfer':
                job_features[0]= 2
                #             print(job_features)
            job_features = [-1 if x != x else x for x in job_features]
            graph['x'].insert(lookup[l], job_features)
        t_list=[]
        for i in range(len(graph['x'])):
            t_list.append(graph['x'][i][1])
        minim= min(t_list)
        for i in range(len(graph['x'])):
            lim = graph['x'][i][1:7]
            lim=[ v-minim for v in lim]
            graph['x'][i][1:7]= lim            
        graphs.append(graph)
# Out:
# casa_nowcast_clustering_16
# cpu_2
# cpu_3
# hdd_100
# hdd_50
# hdd_60
# hdd_70
# hdd_80
# hdd_90
# loss_0.1
# loss_0.5
# loss_1
# loss_3
# loss_5
# normal

# %%
print("casa_nowcast_clustering_8")
counter = 0
edge_index = []
lookup = {}
with open("adjacency_list_dags/casa_nowcast_clustering_8.json", "r") as f:
    adjacency_list = json.load(f)
for l in adjacency_list:
    lookup[l] = counter
    counter+=1
for l in adjacency_list:
    for e in adjacency_list[l]:
        edge_index.append([lookup[l], lookup[e]])     
for d in os.listdir("data"):
    print(d)
    for f in glob.glob(os.path.join("data", d, "nowcast-clustering-8*")):
        graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
        features = pd.read_csv(f, index_col=[0])
        features= features.replace('', -1, regex=True)
        # time_list
        for l in lookup:
            if l.startswith("create_dir_") or l.startswith("cleanup_"):
                new_l = l.split("-")[0]
            else:
                new_l = l
            job_features = features[features.index.str.startswith(new_l)][['type', 'ready',
                                   'submit', 'execute_start', 'execute_end', 'post_script_start',
                                   'post_script_end', 'wms_delay', 'pre_script_delay', 'queue_delay',
                                   'runtime', 'post_script_delay', 'stage_in_delay', 'stage_out_delay']].values.tolist()[0]
            if job_features[0]=='auxiliary':
                job_features[0]= 0
            if job_features[0]=='compute':
                job_features[0]= 1
            if job_features[0]=='transfer':
                job_features[0]= 2
                #             print(job_features)
            job_features = [-1 if x != x else x for x in job_features]
            graph['x'].insert(lookup[l], job_features)
        t_list=[]
        for i in range(len(graph['x'])):
            t_list.append(graph['x'][i][1])
        minim= min(t_list)
        for i in range(len(graph['x'])):
            lim = graph['x'][i][1:7]
            lim=[ v-minim for v in lim]
            graph['x'][i][1:7]= lim
        graphs.append(graph)
# Out:
# casa_nowcast_clustering_8
# cpu_2
# cpu_3
# hdd_100
# hdd_50
# hdd_60
# hdd_70
# hdd_80
# hdd_90
# loss_0.1
# loss_0.5
# loss_1
# loss_3
# loss_5
# normal

# %%
print("casa_wind_clustering")
counter = 0
edge_index = []
lookup = {}
with open("adjacency_list_dags/casa_wind_clustering.json", "r") as f:
    adjacency_list = json.load(f)
for l in adjacency_list:
    lookup[l] = counter
    counter+=1
for l in adjacency_list:
    for e in adjacency_list[l]:
        edge_index.append([lookup[l], lookup[e]])   
for d in os.listdir("data"):
    print(d)
    for f in glob.glob(os.path.join("data", d, "wind-clustering-casa*")):
        graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
        features = pd.read_csv(f, index_col=[0])
        features= features.replace('', -1, regex=True)
        # time_list
        for l in lookup:
            if l.startswith("create_dir_") or l.startswith("cleanup_"):
                new_l = l.split("-")[0]
            else:
                new_l = l
            job_features = features[features.index.str.startswith(new_l)][['type', 'ready',
                                   'submit', 'execute_start', 'execute_end', 'post_script_start',
                                   'post_script_end', 'wms_delay', 'pre_script_delay', 'queue_delay',
                                   'runtime', 'post_script_delay', 'stage_in_delay', 'stage_out_delay']].values.tolist()[0]
            if job_features[0]=='auxiliary':
                job_features[0]= 0
            if job_features[0]=='compute':
                job_features[0]= 1
            if job_features[0]=='transfer':
                job_features[0]= 2
                #             print(job_features)
            job_features = [-1 if x != x else x for x in job_features]
            graph['x'].insert(lookup[l], job_features)
        t_list=[]
        for i in range(len(graph['x'])):
            t_list.append(graph['x'][i][1])
        minim= min(t_list)
        for i in range(len(graph['x'])):
            lim = graph['x'][i][1:7]
            lim=[ v-minim for v in lim]
            graph['x'][i][1:7]= lim
        graphs.append(graph)
# Out:
# casa_wind_clustering
# cpu_2
# cpu_3
# hdd_100
# hdd_50
# hdd_60
# hdd_70
# hdd_80
# hdd_90
# loss_0.1
# loss_0.5
# loss_1
# loss_3
# loss_5
# normal

# %%
print("casa_wind_no_clustering")
counter = 0
edge_index = []
lookup = {}
with open("adjacency_list_dags/casa_wind_no_clustering.json", "r") as f:
    adjacency_list = json.load(f)
for l in adjacency_list:
    lookup[l] = counter
    counter+=1
for l in adjacency_list:
    for e in adjacency_list[l]:
        edge_index.append([lookup[l], lookup[e]])     
for d in os.listdir("data"):
    print(d)
    for f in glob.glob(os.path.join("data", d, "wind-noclustering-casa*")):
        if "-20200817T052029Z-" in f: continue
        graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
        features = pd.read_csv(f, index_col=[0])
        features= features.replace('', -1, regex=True)
        # time_list
        for l in lookup:
            if l.startswith("create_dir_") or l.startswith("cleanup_"):
                new_l = l.split("-")[0]
            else:
                new_l = l
            # print(len(features[features.index.str.startswith(new_l)]) )
            #type,ready,pre_script_start,pre_script_end,submit,execute_start,
            #execute_end,post_script_start,post_script_end,wms_delay,pre_script_delay,
            #queue_delay,runtime,post_script_delay,stage_in_delay,stage_out_delay
            if len(features[features.index.str.startswith(new_l)])<1:
                print(f)
                print(new_l)
                continue
                
            job_features = features[features.index.str.startswith(new_l)][['type', 'ready',
                                   'submit', 'execute_start', 'execute_end', 'post_script_start',
                                   'post_script_end', 'wms_delay', 'pre_script_delay', 'queue_delay',
                                   'runtime', 'post_script_delay', 'stage_in_delay', 'stage_out_delay']].values.tolist()[0]
            if job_features[0]=='auxiliary':
                job_features[0]= 0
            if job_features[0]=='compute':
                job_features[0]= 1
            if job_features[0]=='transfer':
                job_features[0]= 2
                #             print(job_features)
            job_features = [-1 if x != x else x for x in job_features]
            graph['x'].insert(lookup[l], job_features)
        t_list=[]
        for i in range(len(graph['x'])):
            t_list.append(graph['x'][i][1])
        minim= min(t_list)
        for i in range(len(graph['x'])):
            lim = graph['x'][i][1:7]
            lim=[ v-minim for v in lim]
            graph['x'][i][1:7]= lim
        graphs.append(graph)
# Out:
# casa_wind_no_clustering
# cpu_2
# cpu_3
# hdd_100
# hdd_50
# hdd_60
# hdd_70
# hdd_80
# hdd_90
# loss_0.1
# loss_0.5
# loss_1
# loss_3
# loss_5
# normal

# %%
## Dumped into the pickle file.
import pickle
with open('graph_all_.pkl','wb') as f:
    pickle.dump(graphs, f)

# %%
import numpy as np
y_list = []
for gr in graphs:
    y_list.append(gr['y'])
print(min(y_list))
print(max(y_list))
print(np.unique(np.array(y_list), return_counts=True))
# Out:
# 0
# 3
# (array([0, 1, 2, 3]), array([1271, 1440, 2003, 1440]))

# %%
import torch
from torch_geometric.data import Data
datasets=[]
import numpy
for element in graphs:
    gx = torch.tensor(numpy.array(element['x']) ) 
    
    ge =torch.tensor(numpy.array(element['edge_index']) ).T
    gy =torch.tensor(numpy.array(element['y']).reshape([-1]))
    print(gx.shape, ge.shape, gy.shape)
    # print(gy)
    v_min, v_max = gx.min(), gx.max()
    new_min, new_max = -1, 1
    gx = (gx - v_min)/(v_max - v_min)*(new_max - new_min) + new_min
    # print(gx.min(), gx.max())
    datasets.append( Data(x=gx, edge_index=ge, y=gy) )
# Out:
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# torch.Size([57, 14]) torch.Size([2, 129]) torch.Size([1])
# ...
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])
# torch.Size([26, 14]) torch.Size([2, 44]) torch.Size([1])

# %%
import torch
from torch_geometric.datasets import TUDataset

dataset = datasets

# # print()
# # print(f'Dataset: {dataset}:')
# print('====================')
# print(f'Number of graphs: {len(dataset)}')
# # print(f'Number of features: {dataset.num_features}')
# # print(f'Number of classes: {dataset.num_classes}')
# data = dataset[0]  # Get the first graph object.
# print()
# print(data)
# print('=============================================================')
# # Gather some statistics about the first graph.
# print(f'Number of nodes: {data.num_nodes}')
# print(f'Number of edges: {data.num_edges}')
# print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
# print(f'Has isolated nodes: {data.has_isolated_nodes()}')
# print(f'Has self-loops: {data.has_self_loops()}')
# print(f'Is undirected: {data.is_undirected()}')

# %%
torch.manual_seed(12345)
import random
random.seed(12345)
random.shuffle(datasets)
train_dataset = datasets[:5154]
test_dataset = datasets[5154:]

print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')
# Out:
# Number of training graphs: 5154
# Number of test graphs: 1000

# %%
from torch_geometric.loader import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1403, 14], edge_index=[2, 2673], y=[64], batch=[1403], ptr=[65])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1519, 14], edge_index=[2, 2972], y=[64], batch=[1519], ptr=[65])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1308, 14], edge_index=[2, 2468], y=[64], batch=[1308], ptr=[65])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1478, 14], edge_index=[2, 2867], y=[64], batch=[1478], ptr=[65])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1367, 14], edge_index=[2, 2501], y=[64], batch=[1367], ptr=[65])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1756, 14], edge_index=[2, 3499], y=[64], batch=[1756], ptr=[65])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1444, 14], edge_index=[2, 2749], y=[64], batch=[1444], ptr=[65])
#
# Step 8:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1376, 14], edge_index=[2, 2542], y=[64], batch=[1376], ptr=[65])
#
# Step 9:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1648, 14], edge_index=[2, 3216], y=[64], batch=[1648], ptr=[65])
#
# Step 10:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1570, 14], edge_index=[2, 3122], y=[64], batch=[1570], ptr=[65])
#
# Step 11:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1497, 14], edge_index=[2, 2853], y=[64], batch=[1497], ptr=[65])
#
# Step 12:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1494, 14], edge_index=[2, 2895], y=[64], batch=[1494], ptr=[65])
#
# Step 13:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1711, 14], edge_index=[2, 3386], y=[64], batch=[1711], ptr=[65])
#
# Step 14:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1518, 14], edge_index=[2, 2889], y=[64], batch=[1518], ptr=[65])
#
# Step 15:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1633, 14], edge_index=[2, 3238], y=[64], batch=[1633], ptr=[65])
#
# Step 16:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1290, 14], edge_index=[2, 2357], y=[64], batch=[1290], ptr=[65])
#
# Step 17:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1570, 14], edge_index=[2, 3018], y=[64], batch=[1570], ptr=[65])
#
# Step 18:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1825, 14], edge_index=[2, 3685], y=[64], batch=[1825], ptr=[65])
#
# Step 19:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1199, 14], edge_index=[2, 2131], y=[64], batch=[1199], ptr=[65])
#
# Step 20:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1521, 14], edge_index=[2, 2947], y=[64], batch=[1521], ptr=[65])
#
# Step 21:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1237, 14], edge_index=[2, 2282], y=[64], batch=[1237], ptr=[65])
#
# Step 22:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1264, 14], edge_index=[2, 2309], y=[64], batch=[1264], ptr=[65])
#
# Step 23:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1228, 14], edge_index=[2, 2266], y=[64], batch=[1228], ptr=[65])
#
# Step 24:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1504, 14], edge_index=[2, 2840], y=[64], batch=[1504], ptr=[65])
#
# Step 25:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1577, 14], edge_index=[2, 3109], y=[64], batch=[1577], ptr=[65])
#
# Step 26:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1403, 14], edge_index=[2, 2652], y=[64], batch=[1403], ptr=[65])
#
# Step 27:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1354, 14], edge_index=[2, 2552], y=[64], batch=[1354], ptr=[65])
#
# Step 28:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1596, 14], edge_index=[2, 3091], y=[64], batch=[1596], ptr=[65])
#
# Step 29:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1514, 14], edge_index=[2, 2910], y=[64], batch=[1514], ptr=[65])
#
# Step 30:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1624, 14], edge_index=[2, 3222], y=[64], batch=[1624], ptr=[65])
#
# Step 31:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1589, 14], edge_index=[2, 3104], y=[64], batch=[1589], ptr=[65])
#
# Step 32:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1631, 14], edge_index=[2, 3184], y=[64], batch=[1631], ptr=[65])
#
# Step 33:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1600, 14], edge_index=[2, 3099], y=[64], batch=[1600], ptr=[65])
#
# Step 34:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1327, 14], edge_index=[2, 2479], y=[64], batch=[1327], ptr=[65])
#
# Step 35:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1575, 14], edge_index=[2, 3101], y=[64], batch=[1575], ptr=[65])
#
# Step 36:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1250, 14], edge_index=[2, 2306], y=[64], batch=[1250], ptr=[65])
#
# Step 37:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1339, 14], edge_index=[2, 2528], y=[64], batch=[1339], ptr=[65])
#
# Step 38:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1178, 14], edge_index=[2, 2120], y=[64], batch=[1178], ptr=[65])
#
# Step 39:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1589, 14], edge_index=[2, 3129], y=[64], batch=[1589], ptr=[65])
#
# Step 40:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1572, 14], edge_index=[2, 3126], y=[64], batch=[1572], ptr=[65])
#
# Step 41:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1440, 14], edge_index=[2, 2716], y=[64], batch=[1440], ptr=[65])
#
# Step 42:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1325, 14], edge_index=[2, 2504], y=[64], batch=[1325], ptr=[65])
#
# Step 43:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1549, 14], edge_index=[2, 3053], y=[64], batch=[1549], ptr=[65])
#
# Step 44:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1265, 14], edge_index=[2, 2284], y=[64], batch=[1265], ptr=[65])
#
# Step 45:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1551, 14], edge_index=[2, 3007], y=[64], batch=[1551], ptr=[65])
#
# Step 46:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1505, 14], edge_index=[2, 2923], y=[64], batch=[1505], ptr=[65])
#
# Step 47:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1469, 14], edge_index=[2, 2826], y=[64], batch=[1469], ptr=[65])
#
# Step 48:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1302, 14], edge_index=[2, 2377], y=[64], batch=[1302], ptr=[65])
#
# Step 49:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1308, 14], edge_index=[2, 2414], y=[64], batch=[1308], ptr=[65])
#
# Step 50:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1495, 14], edge_index=[2, 2845], y=[64], batch=[1495], ptr=[65])
#
# Step 51:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1623, 14], edge_index=[2, 3222], y=[64], batch=[1623], ptr=[65])
#
# Step 52:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1393, 14], edge_index=[2, 2682], y=[64], batch=[1393], ptr=[65])
#
# Step 53:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1278, 14], edge_index=[2, 2333], y=[64], batch=[1278], ptr=[65])
#
# Step 54:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1457, 14], edge_index=[2, 2802], y=[64], batch=[1457], ptr=[65])
#
# Step 55:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1311, 14], edge_index=[2, 2472], y=[64], batch=[1311], ptr=[65])
#
# Step 56:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1470, 14], edge_index=[2, 2801], y=[64], batch=[1470], ptr=[65])
#
# Step 57:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1323, 14], edge_index=[2, 2471], y=[64], batch=[1323], ptr=[65])
#
# Step 58:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1500, 14], edge_index=[2, 2828], y=[64], batch=[1500], ptr=[65])
#
# Step 59:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1410, 14], edge_index=[2, 2660], y=[64], batch=[1410], ptr=[65])
#
# Step 60:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1806, 14], edge_index=[2, 3620], y=[64], batch=[1806], ptr=[65])
#
# Step 61:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1493, 14], edge_index=[2, 2845], y=[64], batch=[1493], ptr=[65])
#
# Step 62:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1415, 14], edge_index=[2, 2697], y=[64], batch=[1415], ptr=[65])
#
# Step 63:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1341, 14], edge_index=[2, 2553], y=[64], batch=[1341], ptr=[65])
#
# Step 64:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1368, 14], edge_index=[2, 2584], y=[64], batch=[1368], ptr=[65])
#
# Step 65:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1177, 14], edge_index=[2, 2091], y=[64], batch=[1177], ptr=[65])
#
# Step 66:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1130, 14], edge_index=[2, 1974], y=[64], batch=[1130], ptr=[65])
#
# Step 67:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1469, 14], edge_index=[2, 2855], y=[64], batch=[1469], ptr=[65])
#
# Step 68:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1391, 14], edge_index=[2, 2624], y=[64], batch=[1391], ptr=[65])
#
# Step 69:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1383, 14], edge_index=[2, 2583], y=[64], batch=[1383], ptr=[65])
#
# Step 70:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1506, 14], edge_index=[2, 2865], y=[64], batch=[1506], ptr=[65])
#
# Step 71:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1703, 14], edge_index=[2, 3370], y=[64], batch=[1703], ptr=[65])
#
# Step 72:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1413, 14], edge_index=[2, 2668], y=[64], batch=[1413], ptr=[65])
#
# Step 73:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1529, 14], edge_index=[2, 2992], y=[64], batch=[1529], ptr=[65])
#
# Step 74:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1323, 14], edge_index=[2, 2467], y=[64], batch=[1323], ptr=[65])
#
# Step 75:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1293, 14], edge_index=[2, 2386], y=[64], batch=[1293], ptr=[65])
#
# Step 76:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1301, 14], edge_index=[2, 2402], y=[64], batch=[1301], ptr=[65])
#
# Step 77:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1206, 14], edge_index=[2, 2172], y=[64], batch=[1206], ptr=[65])
#
# Step 78:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1567, 14], edge_index=[2, 3089], y=[64], batch=[1567], ptr=[65])
#
# Step 79:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1709, 14], edge_index=[2, 3411], y=[64], batch=[1709], ptr=[65])
#
# Step 80:
# =======
# Number of graphs in the current batch: 64
# DataBatch(x=[1576, 14], edge_index=[2, 3105], y=[64], batch=[1576], ptr=[65])
#
# Step 81:
# =======
# Number of graphs in the current batch: 34
# DataBatch(x=[908, 14], edge_index=[2, 1835], y=[34], batch=[908], ptr=[35])

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, ChebConv, SAGEConv
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = SAGEConv(14, hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 4)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)
        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]
        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        return x

model = GCN(hidden_channels=64)
print(model)
# Out:
# GCN(
#   (conv1): SAGEConv(14, 64)
#   (conv2): SAGEConv(64, 64)
#   (conv3): SAGEConv(64, 64)
#   (lin): Linear(in_features=64, out_features=4, bias=True)
# )

# %%
model = GCN(hidden_channels=64).float()
criterion = torch.nn.CrossEntropyLoss()
# from IPython.display import Javascript
# display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))     
def train():
    model.train()
    for data in train_loader:  # Iterate in batches over the training dataset.
        out = model(data.x.float(), data.edge_index, data.batch)  # Perform a single forward pass.
        loss = criterion(out, data.y)  # Compute the loss.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        optimizer.zero_grad()  # Clear gradients.

def test(loader):
    model.eval()
    correct = 0
    for data in loader:  # Iterate in batches over the training/test dataset.
        out = model(data.x.float(), data.edge_index, data.batch)  
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        correct += int((pred == data.y).sum())  # Check against ground-truth labels.
    return correct / len(loader.dataset)  # Derive ratio of correct predictions.

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
import torch.optim.lr_scheduler as lrs
scheduler = lrs.ExponentialLR(optimizer, gamma=0.9)
for epoch in range(1, 20000):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    if epoch%1000==0:
        scheduler.step()
        print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
        
    if epoch%100==0:
        torch.save(model.state_dict(), 'model_')
# Out:
# Epoch: 1000, Train Acc: 0.6787, Test Acc: 0.6570
# Epoch: 2000, Train Acc: 0.7107, Test Acc: 0.6940
# Epoch: 3000, Train Acc: 0.7286, Test Acc: 0.6900
# Epoch: 4000, Train Acc: 0.7569, Test Acc: 0.7190
# Epoch: 5000, Train Acc: 0.7614, Test Acc: 0.7240
# Epoch: 6000, Train Acc: 0.7699, Test Acc: 0.7210
# Epoch: 7000, Train Acc: 0.7897, Test Acc: 0.7320
# Epoch: 8000, Train Acc: 0.7891, Test Acc: 0.7410
# Epoch: 9000, Train Acc: 0.7930, Test Acc: 0.7290
# Epoch: 10000, Train Acc: 0.8007, Test Acc: 0.7260
# Epoch: 11000, Train Acc: 0.7953, Test Acc: 0.7290
# Epoch: 12000, Train Acc: 0.8050, Test Acc: 0.7320
