# %%
import json
import glob
import os
import pandas as pd
import numpy as np

with open("adjacency_list_dags/1000genome.json", "r") as f:
    adjacency_list = json.load(f)

counter = 0
edge_index = []
lookup = {}
for l in adjacency_list:
    lookup[l] = counter
    counter+=1

for l in adjacency_list:
    for e in adjacency_list[l]:
        edge_index.append([lookup[l], lookup[e]])

# %%
graphs = []
classes = {"normal": 0}
counter = 1
for d in os.listdir("data"):
    d = d.split("_")[0]
    if d in classes: continue
    classes[d] = counter
    counter += 1
    
    
import math
for d in os.listdir("data"):
    for f in glob.glob(os.path.join("data", d, "1000genome*")):
        if f in ["data/cpu_3/1000genome-20200613T072602Z-run0011.csv",
                "data/hdd_100/1000genome-20200901T234910Z-run0048.csv",
                "data/hdd_100/1000genome-20200901T234910Z-run0049.csv",
                "data/loss_1/1000genome-20200520T215721Z-run0014.csv",
                "data/norma/1000genome-20200616T174351Z-run0022.csv"]: continue
            
        print(f)

        graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
        features = pd.read_csv(f, index_col=[0])
        # time_list
        for l in lookup:
            if l.startswith("create_dir_") or l.startswith("cleanup_"):
                new_l = l.split("-")[0]
            else:
                new_l = l
            
            job_features = features[features.index.str.startswith(new_l)][['type', 'is_clustered', 'ready',
                                   'submit', 'execute_start', 'execute_end', 'post_script_start',
                                   'post_script_end', 'wms_delay', 'pre_script_delay', 'queue_delay',
                                   'runtime', 'post_script_delay', 'stage_in_delay', 'stage_out_delay',
                                   'stage_in_bytes', 'stage_out_bytes', 'kickstart_user', 'kickstart_site', 
                                   'kickstart_hostname', 'kickstart_transformations', 'kickstart_executables',
                                   'kickstart_executables_argv', 'kickstart_executables_cpu_time', 'kickstart_status',
                                   'kickstart_executables_exitcode']].values.tolist()[0]

            
            if job_features[0]=='auxiliary':
                job_features[0]= 0
            if job_features[0]=='compute':
                job_features[0]= 1
            if job_features[0]=='transfer':
                job_features[0]= 2
                #             print(job_features)
            job_features = [-1 if x != x else x for x in job_features]
            graph['x'].insert(lookup[l], job_features)

        t_list=[]
        for i in range(len(graph['x'])):
            t_list.append(graph['x'][i][1])
        minim= min(t_list)
        for i in range(len(graph['x'])):
            lim = graph['x'][i][1:7]
            lim=[ v-minim for v in lim]
            graph['x'][i][1:7]= lim
        graphs.append(graph)
#graphs should have the input for pytorch geometric
# Out:
# data/loss_5/1000genome-20200522T184404Z-run0007.csv
# data/loss_5/1000genome-20200522T184404Z-run0040.csv
# data/loss_5/1000genome-20200522T184404Z-run0043.csv
# data/loss_5/1000genome-20200522T184404Z-run0023.csv
# data/loss_5/1000genome-20200522T184404Z-run0045.csv
# data/loss_5/1000genome-20200522T184404Z-run0016.csv
# data/loss_5/1000genome-20200522T184404Z-run0036.csv
# data/loss_5/1000genome-20200522T184404Z-run0020.csv
# data/loss_5/1000genome-20200522T184404Z-run0042.csv
# data/loss_5/1000genome-20200522T184404Z-run0030.csv
# data/loss_5/1000genome-20200522T184404Z-run0048.csv
# data/loss_5/1000genome-20200522T184404Z-run0018.csv
# data/loss_5/1000genome-20200522T184404Z-run0044.csv
# data/loss_5/1000genome-20200522T184404Z-run0015.csv
# data/loss_5/1000genome-20200522T184404Z-run0049.csv
# data/loss_5/1000genome-20200522T184404Z-run0021.csv
# data/loss_5/1000genome-20200522T184404Z-run0008.csv
# data/loss_5/1000genome-20200522T184404Z-run0047.csv
# data/loss_5/1000genome-20200522T184404Z-run0032.csv
# data/loss_5/1000genome-20200522T184404Z-run0002.csv
# data/loss_5/1000genome-20200522T184404Z-run0006.csv
# data/loss_5/1000genome-20200522T184404Z-run0014.csv
# data/loss_5/1000genome-20200522T184404Z-run0041.csv
# data/loss_5/1000genome-20200522T184404Z-run0024.csv
# data/loss_5/1000genome-20200522T184404Z-run0009.csv
# data/loss_5/1000genome-20200522T184404Z-run0046.csv
# data/loss_5/1000genome-20200522T184404Z-run0001.csv
# data/loss_5/1000genome-20200522T184404Z-run0026.csv
# data/loss_5/1000genome-20200522T184404Z-run0033.csv
# data/loss_5/1000genome-20200522T184404Z-run0027.csv
# data/loss_5/1000genome-20200522T184404Z-run0034.csv
# data/loss_5/1000genome-20200522T184404Z-run0011.csv
# data/loss_5/1000genome-20200522T184404Z-run0029.csv
# data/loss_5/1000genome-20200522T184404Z-run0050.csv
# data/loss_5/1000genome-20200522T184404Z-run0028.csv
# data/loss_5/1000genome-20200522T184404Z-run0013.csv
# data/loss_5/1000genome-20200522T184404Z-run0010.csv
# data/loss_5/1000genome-20200522T184404Z-run0012.csv
# data/loss_5/1000genome-20200522T184404Z-run0031.csv
# data/loss_5/1000genome-20200522T184404Z-run0025.csv
# data/loss_5/1000genome-20200522T184404Z-run0035.csv
# data/loss_5/1000genome-20200522T184404Z-run0039.csv
# data/loss_5/1000genome-20200522T184404Z-run0004.csv
# data/loss_5/1000genome-20200522T184404Z-run0022.csv
# data/loss_5/1000genome-20200522T184404Z-run0038.csv
# data/loss_5/1000genome-20200522T184404Z-run0019.csv
# data/loss_5/1000genome-20200522T184404Z-run0037.csv
# data/loss_5/1000genome-20200522T184404Z-run0005.csv
# data/loss_5/1000genome-20200522T184404Z-run0003.csv
# data/loss_5/1000genome-20200522T184404Z-run0017.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0017.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0026.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0019.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0037.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0020.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0045.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0001.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0011.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0013.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0042.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0022.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0014.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0023.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0040.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0008.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0015.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0009.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0041.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0024.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0050.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0033.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0047.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0021.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0048.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0025.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0027.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0012.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0038.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0031.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0043.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0044.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0046.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0006.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0007.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0029.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0016.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0032.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0035.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0039.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0018.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0036.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0028.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0010.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0030.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0002.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0005.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0003.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0034.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0004.csv
# data/loss_0.5/1000genome-20200520T031010Z-run0049.csv
# data/loss_3/1000genome-20200521T193903Z-run0011.csv
# data/loss_3/1000genome-20200521T193903Z-run0025.csv
# data/loss_3/1000genome-20200521T193903Z-run0002.csv
# data/loss_3/1000genome-20200521T193903Z-run0037.csv
# data/loss_3/1000genome-20200521T193903Z-run0008.csv
# data/loss_3/1000genome-20200521T193903Z-run0024.csv
# data/loss_3/1000genome-20200521T193903Z-run0033.csv
# data/loss_3/1000genome-20200521T193903Z-run0012.csv
# data/loss_3/1000genome-20200521T193903Z-run0014.csv
# data/loss_3/1000genome-20200521T193903Z-run0040.csv
# data/loss_3/1000genome-20200521T193903Z-run0010.csv
# data/loss_3/1000genome-20200521T193903Z-run0046.csv
# data/loss_3/1000genome-20200521T193903Z-run0034.csv
# data/loss_3/1000genome-20200521T193903Z-run0004.csv
# data/loss_3/1000genome-20200521T193903Z-run0039.csv
# data/loss_3/1000genome-20200521T193903Z-run0021.csv
# data/loss_3/1000genome-20200521T193903Z-run0015.csv
# data/loss_3/1000genome-20200521T193903Z-run0013.csv
# data/loss_3/1000genome-20200521T193903Z-run0032.csv
# data/loss_3/1000genome-20200521T193903Z-run0050.csv
# data/loss_3/1000genome-20200521T193903Z-run0009.csv
# data/loss_3/1000genome-20200521T193903Z-run0017.csv
# data/loss_3/1000genome-20200521T193903Z-run0041.csv
# data/loss_3/1000genome-20200521T193903Z-run0028.csv
# data/loss_3/1000genome-20200521T193903Z-run0016.csv
# data/loss_3/1000genome-20200521T193903Z-run0048.csv
# data/loss_3/1000genome-20200521T193903Z-run0006.csv
# data/loss_3/1000genome-20200521T193903Z-run0007.csv
# data/loss_3/1000genome-20200521T193903Z-run0023.csv
# data/loss_3/1000genome-20200521T193903Z-run0019.csv
# data/loss_3/1000genome-20200521T193903Z-run0047.csv
# data/loss_3/1000genome-20200521T193903Z-run0038.csv
# data/loss_3/1000genome-20200521T193903Z-run0031.csv
# data/loss_3/1000genome-20200521T193903Z-run0029.csv
# data/loss_3/1000genome-20200521T193903Z-run0045.csv
# data/loss_3/1000genome-20200521T193903Z-run0049.csv
# data/loss_3/1000genome-20200521T193903Z-run0027.csv
# data/loss_3/1000genome-20200521T193903Z-run0043.csv
# data/loss_3/1000genome-20200521T193903Z-run0005.csv
# data/loss_3/1000genome-20200521T193903Z-run0035.csv
# data/loss_3/1000genome-20200521T193903Z-run0003.csv
# data/loss_3/1000genome-20200521T193903Z-run0030.csv
# data/loss_3/1000genome-20200521T193903Z-run0042.csv
# data/loss_3/1000genome-20200521T193903Z-run0022.csv
# data/loss_3/1000genome-20200521T193903Z-run0036.csv
# data/loss_3/1000genome-20200521T193903Z-run0001.csv
# data/loss_3/1000genome-20200521T193903Z-run0026.csv
# data/loss_3/1000genome-20200521T193903Z-run0044.csv
# data/loss_3/1000genome-20200521T193903Z-run0018.csv
# data/loss_3/1000genome-20200521T193903Z-run0020.csv
# data/hdd_50/1000genome-20200610T041238Z-run0006.csv
# data/hdd_50/1000genome-20200922T030313Z-run0036.csv
# data/hdd_50/1000genome-20200610T041238Z-run0032.csv
# data/hdd_50/1000genome-20200610T041238Z-run0027.csv
# data/hdd_50/1000genome-20200610T041238Z-run0044.csv
# data/hdd_50/1000genome-20200829T064317Z-run0043.csv
# data/hdd_50/1000genome-20200610T041238Z-run0010.csv
# data/hdd_50/1000genome-20200610T041238Z-run0022.csv
# data/hdd_50/1000genome-20200610T041238Z-run0007.csv
# data/hdd_50/1000genome-20200610T041238Z-run0050.csv
# data/hdd_50/1000genome-20200610T041238Z-run0036.csv
# data/hdd_50/1000genome-20200922T030313Z-run0030.csv
# data/hdd_50/1000genome-20200922T030313Z-run0004.csv
# data/hdd_50/1000genome-20200610T041238Z-run0048.csv
# data/hdd_50/1000genome-20200610T041238Z-run0030.csv
# data/hdd_50/1000genome-20200829T064317Z-run0019.csv
# data/hdd_50/1000genome-20200829T064317Z-run0049.csv
# data/hdd_50/1000genome-20200829T064317Z-run0036.csv
# data/hdd_50/1000genome-20200922T030313Z-run0047.csv
# data/hdd_50/1000genome-20200922T030313Z-run0011.csv
# data/hdd_50/1000genome-20200922T030313Z-run0031.csv
# data/hdd_50/1000genome-20200610T041238Z-run0017.csv
# data/hdd_50/1000genome-20200829T064317Z-run0028.csv
# data/hdd_50/1000genome-20200922T030313Z-run0015.csv
# data/hdd_50/1000genome-20200922T030313Z-run0012.csv
# data/hdd_50/1000genome-20200922T030313Z-run0043.csv
# data/hdd_50/1000genome-20200829T064317Z-run0038.csv
# data/hdd_50/1000genome-20200829T064317Z-run0042.csv
# data/hdd_50/1000genome-20200610T041238Z-run0040.csv
# data/hdd_50/1000genome-20200610T041238Z-run0024.csv
# data/hdd_50/1000genome-20200922T030313Z-run0038.csv
# data/hdd_50/1000genome-20200829T064317Z-run0004.csv
# data/hdd_50/1000genome-20200610T041238Z-run0004.csv
# data/hdd_50/1000genome-20200922T030313Z-run0007.csv
# data/hdd_50/1000genome-20200829T064317Z-run0026.csv
# data/hdd_50/1000genome-20200829T064317Z-run0035.csv
# data/hdd_50/1000genome-20200922T030313Z-run0006.csv
# data/hdd_50/1000genome-20200610T041238Z-run0026.csv
# data/hdd_50/1000genome-20200829T064317Z-run0048.csv
# data/hdd_50/1000genome-20200829T064317Z-run0040.csv
# data/hdd_50/1000genome-20200610T041238Z-run0029.csv
# data/hdd_50/1000genome-20200610T041238Z-run0037.csv
# data/hdd_50/1000genome-20200829T064317Z-run0033.csv
# data/hdd_50/1000genome-20200922T030313Z-run0035.csv
# data/hdd_50/1000genome-20200922T030313Z-run0037.csv
# data/hdd_50/1000genome-20200610T041238Z-run0008.csv
# data/hdd_50/1000genome-20200829T064317Z-run0023.csv
# data/hdd_50/1000genome-20200922T030313Z-run0027.csv
# data/hdd_50/1000genome-20200922T030313Z-run0046.csv
# data/hdd_50/1000genome-20200829T064317Z-run0027.csv
# data/hdd_50/1000genome-20200922T030313Z-run0039.csv
# data/hdd_50/1000genome-20200829T064317Z-run0029.csv
# data/hdd_50/1000genome-20200610T041238Z-run0002.csv
# data/hdd_50/1000genome-20200922T030313Z-run0001.csv
# data/hdd_50/1000genome-20200922T030313Z-run0025.csv
# data/hdd_50/1000genome-20200829T064317Z-run0007.csv
# data/hdd_50/1000genome-20200922T030313Z-run0023.csv
# data/hdd_50/1000genome-20200829T064317Z-run0013.csv
# data/hdd_50/1000genome-20200922T030313Z-run0032.csv
# data/hdd_50/1000genome-20200610T041238Z-run0039.csv
# data/hdd_50/1000genome-20200922T030313Z-run0024.csv
# data/hdd_50/1000genome-20200610T041238Z-run0020.csv
# data/hdd_50/1000genome-20200922T030313Z-run0048.csv
# data/hdd_50/1000genome-20200829T064317Z-run0047.csv
# data/hdd_50/1000genome-20200829T064317Z-run0012.csv
# data/hdd_50/1000genome-20200610T041238Z-run0042.csv
# data/hdd_50/1000genome-20200610T041238Z-run0009.csv
# data/hdd_50/1000genome-20200829T064317Z-run0010.csv
# data/hdd_50/1000genome-20200829T064317Z-run0008.csv
# data/hdd_50/1000genome-20200829T064317Z-run0030.csv
# data/hdd_50/1000genome-20200922T030313Z-run0034.csv
# data/hdd_50/1000genome-20200610T041238Z-run0005.csv
# data/hdd_50/1000genome-20200610T041238Z-run0038.csv
# data/hdd_50/1000genome-20200610T041238Z-run0023.csv
# data/hdd_50/1000genome-20200829T064317Z-run0041.csv
# data/hdd_50/1000genome-20200610T041238Z-run0011.csv
# data/hdd_50/1000genome-20200922T030313Z-run0033.csv
# data/hdd_50/1000genome-20200610T041238Z-run0043.csv
# data/hdd_50/1000genome-20200922T030313Z-run0026.csv
# data/hdd_50/1000genome-20200922T030313Z-run0021.csv
# data/hdd_50/1000genome-20200610T041238Z-run0028.csv
# data/hdd_50/1000genome-20200829T064317Z-run0002.csv
# data/hdd_50/1000genome-20200922T030313Z-run0010.csv
# data/hdd_50/1000genome-20200829T064317Z-run0046.csv
# data/hdd_50/1000genome-20200922T030313Z-run0045.csv
# data/hdd_50/1000genome-20200829T064317Z-run0039.csv
# data/hdd_50/1000genome-20200922T030313Z-run0003.csv
# data/hdd_50/1000genome-20200829T064317Z-run0031.csv
# data/hdd_50/1000genome-20200829T064317Z-run0016.csv
# data/hdd_50/1000genome-20200829T064317Z-run0050.csv
# data/hdd_50/1000genome-20200829T064317Z-run0032.csv
# data/hdd_50/1000genome-20200610T041238Z-run0013.csv
# data/hdd_50/1000genome-20200922T030313Z-run0028.csv
# data/hdd_50/1000genome-20200829T064317Z-run0025.csv
# data/hdd_50/1000genome-20200829T064317Z-run0009.csv
# data/hdd_50/1000genome-20200610T041238Z-run0025.csv
# data/hdd_50/1000genome-20200829T064317Z-run0017.csv
# data/hdd_50/1000genome-20200922T030313Z-run0044.csv
# data/hdd_50/1000genome-20200829T064317Z-run0001.csv
# data/hdd_50/1000genome-20200922T030313Z-run0014.csv
# data/hdd_50/1000genome-20200829T064317Z-run0005.csv
# data/hdd_50/1000genome-20200829T064317Z-run0024.csv
# data/hdd_50/1000genome-20200922T030313Z-run0041.csv
# data/hdd_50/1000genome-20200829T064317Z-run0045.csv
# data/hdd_50/1000genome-20200610T041238Z-run0041.csv
# data/hdd_50/1000genome-20200610T041238Z-run0045.csv
# data/hdd_50/1000genome-20200829T064317Z-run0014.csv
# data/hdd_50/1000genome-20200610T041238Z-run0033.csv
# data/hdd_50/1000genome-20200829T064317Z-run0018.csv
# data/hdd_50/1000genome-20200829T064317Z-run0022.csv
# data/hdd_50/1000genome-20200922T030313Z-run0018.csv
# data/hdd_50/1000genome-20200829T064317Z-run0020.csv
# data/hdd_50/1000genome-20200922T030313Z-run0002.csv
# data/hdd_50/1000genome-20200922T030313Z-run0017.csv
# data/hdd_50/1000genome-20200922T030313Z-run0013.csv
# data/hdd_50/1000genome-20200610T041238Z-run0021.csv
# data/hdd_50/1000genome-20200922T030313Z-run0008.csv
# data/hdd_50/1000genome-20200610T041238Z-run0049.csv
# data/hdd_50/1000genome-20200829T064317Z-run0003.csv
# data/hdd_50/1000genome-20200922T030313Z-run0005.csv
# data/hdd_50/1000genome-20200829T064317Z-run0015.csv
# data/hdd_50/1000genome-20200829T064317Z-run0037.csv
# data/hdd_50/1000genome-20200610T041238Z-run0046.csv
# data/hdd_50/1000genome-20200922T030313Z-run0042.csv
# data/hdd_50/1000genome-20200922T030313Z-run0022.csv
# data/hdd_50/1000genome-20200829T064317Z-run0044.csv
# data/hdd_50/1000genome-20200922T030313Z-run0029.csv
# data/hdd_50/1000genome-20200610T041238Z-run0047.csv
# data/hdd_50/1000genome-20200610T041238Z-run0031.csv
# data/hdd_50/1000genome-20200922T030313Z-run0020.csv
# data/hdd_50/1000genome-20200610T041238Z-run0014.csv
# data/hdd_50/1000genome-20200922T030313Z-run0049.csv
# data/hdd_50/1000genome-20200922T030313Z-run0009.csv
# data/hdd_50/1000genome-20200610T041238Z-run0012.csv
# data/hdd_50/1000genome-20200610T041238Z-run0019.csv
# data/hdd_50/1000genome-20200922T030313Z-run0040.csv
# data/hdd_50/1000genome-20200829T064317Z-run0011.csv
# data/hdd_50/1000genome-20200610T041238Z-run0003.csv
# data/hdd_50/1000genome-20200610T041238Z-run0018.csv
# data/hdd_50/1000genome-20200922T030313Z-run0016.csv
# data/hdd_50/1000genome-20200610T041238Z-run0001.csv
# data/hdd_50/1000genome-20200829T064317Z-run0021.csv
# data/hdd_50/1000genome-20200610T041238Z-run0016.csv
# data/hdd_50/1000genome-20200829T064317Z-run0034.csv
# data/hdd_50/1000genome-20200610T041238Z-run0035.csv
# data/hdd_50/1000genome-20200922T030313Z-run0050.csv
# data/hdd_50/1000genome-20200922T030313Z-run0019.csv
# data/hdd_50/1000genome-20200610T041238Z-run0034.csv
# data/hdd_50/1000genome-20200829T064317Z-run0006.csv
# data/hdd_50/1000genome-20200610T041238Z-run0015.csv
# data/hdd_100/1000genome-20200925T032904Z-run0012.csv
# data/hdd_100/1000genome-20200901T234910Z-run0013.csv
# data/hdd_100/1000genome-20200615T062813Z-run0038.csv
# data/hdd_100/1000genome-20200615T062813Z-run0046.csv
# data/hdd_100/1000genome-20200901T234910Z-run0045.csv
# data/hdd_100/1000genome-20200901T234910Z-run0024.csv
# data/hdd_100/1000genome-20200615T062813Z-run0019.csv
# data/hdd_100/1000genome-20200901T234910Z-run0023.csv
# data/hdd_100/1000genome-20200615T062813Z-run0030.csv
# data/hdd_100/1000genome-20200901T234910Z-run0016.csv
# data/hdd_100/1000genome-20200615T062813Z-run0041.csv
# data/hdd_100/1000genome-20200615T062813Z-run0006.csv
# data/hdd_100/1000genome-20200925T032904Z-run0006.csv
# data/hdd_100/1000genome-20200615T062813Z-run0008.csv
# data/hdd_100/1000genome-20200901T234910Z-run0035.csv
# data/hdd_100/1000genome-20200925T032904Z-run0016.csv
# data/hdd_100/1000genome-20200901T234910Z-run0004.csv
# data/hdd_100/1000genome-20200901T234910Z-run0007.csv
# data/hdd_100/1000genome-20200615T062813Z-run0003.csv
# data/hdd_100/1000genome-20200615T062813Z-run0027.csv
# data/hdd_100/1000genome-20200615T062813Z-run0005.csv
# data/hdd_100/1000genome-20200901T234910Z-run0020.csv
# data/hdd_100/1000genome-20200615T062813Z-run0021.csv
# data/hdd_100/1000genome-20200901T234910Z-run0025.csv
# data/hdd_100/1000genome-20200901T234910Z-run0031.csv
# data/hdd_100/1000genome-20200901T234910Z-run0033.csv
# data/hdd_100/1000genome-20200615T062813Z-run0011.csv
# data/hdd_100/1000genome-20200901T234910Z-run0012.csv
# data/hdd_100/1000genome-20200901T234910Z-run0028.csv
# data/hdd_100/1000genome-20200615T062813Z-run0026.csv
# data/hdd_100/1000genome-20200925T032904Z-run0015.csv
# data/hdd_100/1000genome-20200615T062813Z-run0028.csv
# data/hdd_100/1000genome-20200925T032904Z-run0018.csv
# data/hdd_100/1000genome-20200615T062813Z-run0017.csv
# data/hdd_100/1000genome-20200925T032904Z-run0013.csv
# data/hdd_100/1000genome-20200901T234910Z-run0027.csv
# data/hdd_100/1000genome-20200925T032904Z-run0022.csv
# data/hdd_100/1000genome-20200901T234910Z-run0041.csv
# data/hdd_100/1000genome-20200615T062813Z-run0013.csv
# data/hdd_100/1000genome-20200615T062813Z-run0007.csv
# data/hdd_100/1000genome-20200615T062813Z-run0025.csv
# data/hdd_100/1000genome-20200901T234910Z-run0037.csv
# data/hdd_100/1000genome-20200901T234910Z-run0015.csv
# data/hdd_100/1000genome-20200925T032904Z-run0017.csv
# data/hdd_100/1000genome-20200615T062813Z-run0020.csv
# data/hdd_100/1000genome-20200615T062813Z-run0023.csv
# data/hdd_100/1000genome-20200615T062813Z-run0001.csv
# data/hdd_100/1000genome-20200901T234910Z-run0044.csv
# data/hdd_100/1000genome-20200615T062813Z-run0032.csv
# data/hdd_100/1000genome-20200925T032904Z-run0007.csv
# data/hdd_100/1000genome-20200901T234910Z-run0008.csv
# data/hdd_100/1000genome-20200901T234910Z-run0042.csv
# data/hdd_100/1000genome-20200901T234910Z-run0010.csv
# data/hdd_100/1000genome-20200925T032904Z-run0001.csv
# data/hdd_100/1000genome-20200925T032904Z-run0025.csv
# data/hdd_100/1000genome-20200901T234910Z-run0043.csv
# data/hdd_100/1000genome-20200901T234910Z-run0019.csv
# data/hdd_100/1000genome-20200901T234910Z-run0005.csv
# data/hdd_100/1000genome-20200925T032904Z-run0019.csv
# data/hdd_100/1000genome-20200925T032904Z-run0023.csv
# data/hdd_100/1000genome-20200901T234910Z-run0036.csv
# data/hdd_100/1000genome-20200615T062813Z-run0036.csv
# data/hdd_100/1000genome-20200615T062813Z-run0024.csv
# data/hdd_100/1000genome-20200925T032904Z-run0014.csv
# data/hdd_100/1000genome-20200615T062813Z-run0014.csv
# data/hdd_100/1000genome-20200925T032904Z-run0002.csv
# data/hdd_100/1000genome-20200901T234910Z-run0046.csv
# data/hdd_100/1000genome-20200901T234910Z-run0032.csv
# data/hdd_100/1000genome-20200615T062813Z-run0049.csv
# data/hdd_100/1000genome-20200615T062813Z-run0048.csv
# data/hdd_100/1000genome-20200901T234910Z-run0014.csv
# data/hdd_100/1000genome-20200615T062813Z-run0016.csv
# data/hdd_100/1000genome-20200615T062813Z-run0022.csv
# data/hdd_100/1000genome-20200615T062813Z-run0029.csv
# data/hdd_100/1000genome-20200901T234910Z-run0003.csv
# data/hdd_100/1000genome-20200901T234910Z-run0006.csv
# data/hdd_100/1000genome-20200925T032904Z-run0011.csv
# data/hdd_100/1000genome-20200901T234910Z-run0026.csv
# data/hdd_100/1000genome-20200925T032904Z-run0003.csv
# data/hdd_100/1000genome-20200615T062813Z-run0034.csv
# data/hdd_100/1000genome-20200925T032904Z-run0005.csv
# data/hdd_100/1000genome-20200901T234910Z-run0040.csv
# data/hdd_100/1000genome-20200901T234910Z-run0001.csv
# data/hdd_100/1000genome-20200615T062813Z-run0035.csv
# data/hdd_100/1000genome-20200901T234910Z-run0029.csv
# data/hdd_100/1000genome-20200901T234910Z-run0034.csv
# data/hdd_100/1000genome-20200615T062813Z-run0045.csv
# data/hdd_100/1000genome-20200925T032904Z-run0021.csv
# data/hdd_100/1000genome-20200925T032904Z-run0008.csv
# data/hdd_100/1000genome-20200901T234910Z-run0047.csv
# data/hdd_100/1000genome-20200901T234910Z-run0038.csv
# data/hdd_100/1000genome-20200901T234910Z-run0039.csv
# data/hdd_100/1000genome-20200901T234910Z-run0018.csv
# data/hdd_100/1000genome-20200901T234910Z-run0021.csv
# data/hdd_100/1000genome-20200615T062813Z-run0018.csv
# data/hdd_100/1000genome-20200901T234910Z-run0011.csv
# data/hdd_100/1000genome-20200901T234910Z-run0009.csv
# data/hdd_100/1000genome-20200615T062813Z-run0010.csv
# data/hdd_100/1000genome-20200901T234910Z-run0050.csv
# data/hdd_100/1000genome-20200615T062813Z-run0031.csv
# data/hdd_100/1000genome-20200615T062813Z-run0012.csv
# data/hdd_100/1000genome-20200615T062813Z-run0002.csv
# data/hdd_100/1000genome-20200615T062813Z-run0015.csv
# data/hdd_100/1000genome-20200615T062813Z-run0050.csv
# data/hdd_100/1000genome-20200925T032904Z-run0010.csv
# data/hdd_100/1000genome-20200615T062813Z-run0004.csv
# data/hdd_100/1000genome-20200901T234910Z-run0017.csv
# data/hdd_100/1000genome-20200901T234910Z-run0002.csv
# data/hdd_100/1000genome-20200615T062813Z-run0043.csv
# data/hdd_100/1000genome-20200925T032904Z-run0009.csv
# data/hdd_100/1000genome-20200615T062813Z-run0039.csv
# data/hdd_100/1000genome-20200925T032904Z-run0024.csv
# data/hdd_100/1000genome-20200615T062813Z-run0042.csv
# data/hdd_100/1000genome-20200925T032904Z-run0020.csv
# data/hdd_100/1000genome-20200901T234910Z-run0030.csv
# data/hdd_100/1000genome-20200615T062813Z-run0033.csv
# data/hdd_100/1000genome-20200615T062813Z-run0047.csv
# data/hdd_100/1000genome-20200901T234910Z-run0022.csv
# data/hdd_100/1000genome-20200615T062813Z-run0037.csv
# data/hdd_100/1000genome-20200615T062813Z-run0040.csv
# data/hdd_100/1000genome-20200925T032904Z-run0004.csv
# data/hdd_100/1000genome-20200615T062813Z-run0009.csv
# data/hdd_100/1000genome-20200615T062813Z-run0044.csv
# data/cpu_3/1000genome-20200613T072602Z-run0039.csv
# data/cpu_3/1000genome-20200926T223304Z-run0009.csv
# data/cpu_3/1000genome-20200926T223304Z-run0038.csv
# data/cpu_3/1000genome-20200926T223304Z-run0032.csv
# data/cpu_3/1000genome-20200613T072602Z-run0001.csv
# data/cpu_3/1000genome-20200926T223304Z-run0015.csv
# data/cpu_3/1000genome-20200613T072602Z-run0004.csv
# data/cpu_3/1000genome-20200926T223304Z-run0027.csv
# data/cpu_3/1000genome-20200926T223304Z-run0021.csv
# data/cpu_3/1000genome-20200613T072602Z-run0028.csv
# data/cpu_3/1000genome-20200926T223304Z-run0031.csv
# data/cpu_3/1000genome-20200613T072602Z-run0020.csv
# data/cpu_3/1000genome-20200926T223304Z-run0046.csv
# data/cpu_3/1000genome-20200926T223304Z-run0047.csv
# data/cpu_3/1000genome-20200613T072602Z-run0014.csv
# data/cpu_3/1000genome-20200613T072602Z-run0023.csv
# data/cpu_3/1000genome-20200926T223304Z-run0039.csv
# data/cpu_3/1000genome-20200827T023335Z-run0009.csv
# data/cpu_3/1000genome-20200926T223304Z-run0004.csv
# data/cpu_3/1000genome-20200926T223304Z-run0007.csv
# data/cpu_3/1000genome-20200613T072602Z-run0048.csv
# data/cpu_3/1000genome-20200926T223304Z-run0033.csv
# data/cpu_3/1000genome-20200926T223304Z-run0030.csv
# data/cpu_3/1000genome-20200613T072602Z-run0037.csv
# data/cpu_3/1000genome-20200613T072602Z-run0034.csv
# data/cpu_3/1000genome-20200926T223304Z-run0042.csv
# data/cpu_3/1000genome-20200613T072602Z-run0007.csv
# data/cpu_3/1000genome-20200613T072602Z-run0031.csv
# data/cpu_3/1000genome-20200613T072602Z-run0021.csv
# data/cpu_3/1000genome-20200827T023335Z-run0018.csv
# data/cpu_3/1000genome-20200926T223304Z-run0017.csv
# data/cpu_3/1000genome-20200926T223304Z-run0037.csv
# data/cpu_3/1000genome-20200827T023335Z-run0024.csv
# data/cpu_3/1000genome-20200926T223304Z-run0020.csv
# data/cpu_3/1000genome-20200926T223304Z-run0008.csv
# data/cpu_3/1000genome-20200827T023335Z-run0019.csv
# data/cpu_3/1000genome-20200926T223304Z-run0019.csv
# data/cpu_3/1000genome-20200613T072602Z-run0003.csv
# data/cpu_3/1000genome-20200926T223304Z-run0044.csv
# data/cpu_3/1000genome-20200613T072602Z-run0015.csv
# data/cpu_3/1000genome-20200613T072602Z-run0010.csv
# data/cpu_3/1000genome-20200827T023335Z-run0007.csv
# data/cpu_3/1000genome-20200827T023335Z-run0012.csv
# data/cpu_3/1000genome-20200613T072602Z-run0049.csv
# data/cpu_3/1000genome-20200613T072602Z-run0038.csv
# data/cpu_3/1000genome-20200827T023335Z-run0022.csv
# data/cpu_3/1000genome-20200926T223304Z-run0018.csv
# data/cpu_3/1000genome-20200827T023335Z-run0001.csv
# data/cpu_3/1000genome-20200926T223304Z-run0034.csv
# data/cpu_3/1000genome-20200827T023335Z-run0015.csv
# data/cpu_3/1000genome-20200613T072602Z-run0005.csv
# data/cpu_3/1000genome-20200613T072602Z-run0013.csv
# data/cpu_3/1000genome-20200926T223304Z-run0025.csv
# data/cpu_3/1000genome-20200613T072602Z-run0022.csv
# data/cpu_3/1000genome-20200926T223304Z-run0002.csv
# data/cpu_3/1000genome-20200926T223304Z-run0041.csv
# data/cpu_3/1000genome-20200926T223304Z-run0010.csv
# data/cpu_3/1000genome-20200613T072602Z-run0030.csv
# data/cpu_3/1000genome-20200926T223304Z-run0040.csv
# data/cpu_3/1000genome-20200613T072602Z-run0043.csv
# data/cpu_3/1000genome-20200827T023335Z-run0023.csv
# data/cpu_3/1000genome-20200613T072602Z-run0041.csv
# data/cpu_3/1000genome-20200926T223304Z-run0049.csv
# data/cpu_3/1000genome-20200613T072602Z-run0018.csv
# data/cpu_3/1000genome-20200926T223304Z-run0036.csv
# data/cpu_3/1000genome-20200926T223304Z-run0026.csv
# data/cpu_3/1000genome-20200926T223304Z-run0011.csv
# data/cpu_3/1000genome-20200613T072602Z-run0006.csv
# data/cpu_3/1000genome-20200613T072602Z-run0027.csv
# data/cpu_3/1000genome-20200613T072602Z-run0026.csv
# data/cpu_3/1000genome-20200926T223304Z-run0013.csv
# data/cpu_3/1000genome-20200827T023335Z-run0004.csv
# data/cpu_3/1000genome-20200926T223304Z-run0005.csv
# data/cpu_3/1000genome-20200613T072602Z-run0045.csv
# data/cpu_3/1000genome-20200926T223304Z-run0028.csv
# data/cpu_3/1000genome-20200613T072602Z-run0035.csv
# data/cpu_3/1000genome-20200613T072602Z-run0019.csv
# data/cpu_3/1000genome-20200827T023335Z-run0010.csv
# data/cpu_3/1000genome-20200926T223304Z-run0016.csv
# data/cpu_3/1000genome-20200613T072602Z-run0012.csv
# data/cpu_3/1000genome-20200613T072602Z-run0025.csv
# data/cpu_3/1000genome-20200926T223304Z-run0001.csv
# data/cpu_3/1000genome-20200926T223304Z-run0048.csv
# data/cpu_3/1000genome-20200613T072602Z-run0044.csv
# data/cpu_3/1000genome-20200613T072602Z-run0024.csv
# data/cpu_3/1000genome-20200827T023335Z-run0006.csv
# data/cpu_3/1000genome-20200827T023335Z-run0016.csv
# data/cpu_3/1000genome-20200613T072602Z-run0017.csv
# data/cpu_3/1000genome-20200827T023335Z-run0020.csv
# data/cpu_3/1000genome-20200926T223304Z-run0006.csv
# data/cpu_3/1000genome-20200827T023335Z-run0005.csv
# data/cpu_3/1000genome-20200613T072602Z-run0033.csv
# data/cpu_3/1000genome-20200827T023335Z-run0017.csv
# data/cpu_3/1000genome-20200926T223304Z-run0035.csv
# data/cpu_3/1000genome-20200613T072602Z-run0016.csv
# data/cpu_3/1000genome-20200827T023335Z-run0002.csv
# data/cpu_3/1000genome-20200613T072602Z-run0036.csv
# data/cpu_3/1000genome-20200613T072602Z-run0002.csv
# data/cpu_3/1000genome-20200926T223304Z-run0023.csv
# data/cpu_3/1000genome-20200613T072602Z-run0009.csv
# data/cpu_3/1000genome-20200613T072602Z-run0042.csv
# data/cpu_3/1000genome-20200613T072602Z-run0046.csv
# data/cpu_3/1000genome-20200613T072602Z-run0040.csv
# data/cpu_3/1000genome-20200613T072602Z-run0050.csv
# data/cpu_3/1000genome-20200613T072602Z-run0008.csv
# data/cpu_3/1000genome-20200613T072602Z-run0032.csv
# data/cpu_3/1000genome-20200926T223304Z-run0024.csv
# data/cpu_3/1000genome-20200926T223304Z-run0022.csv
# data/cpu_3/1000genome-20200926T223304Z-run0029.csv
# data/cpu_3/1000genome-20200827T023335Z-run0014.csv
# data/cpu_3/1000genome-20200827T023335Z-run0021.csv
# data/cpu_3/1000genome-20200827T023335Z-run0008.csv
# data/cpu_3/1000genome-20200827T023335Z-run0013.csv
# data/cpu_3/1000genome-20200926T223304Z-run0012.csv
# data/cpu_3/1000genome-20200926T223304Z-run0045.csv
# data/cpu_3/1000genome-20200827T023335Z-run0025.csv
# data/cpu_3/1000genome-20200613T072602Z-run0047.csv
# data/cpu_3/1000genome-20200926T223304Z-run0003.csv
# data/cpu_3/1000genome-20200613T072602Z-run0029.csv
# data/cpu_3/1000genome-20200827T023335Z-run0003.csv
# data/cpu_3/1000genome-20200926T223304Z-run0043.csv
# data/cpu_3/1000genome-20200926T223304Z-run0014.csv
# data/cpu_3/1000genome-20200827T023335Z-run0011.csv
# data/cpu_3/1000genome-20200926T223304Z-run0050.csv
# data/normal/1000genome-20200826T065300Z-run0032.csv
# data/normal/1000genome-20210109T082603Z-run0013.csv
# data/normal/1000genome-20200616T174351Z-run0021.csv
# data/normal/1000genome-20200616T174351Z-run0044.csv
# data/normal/1000genome-20200826T065300Z-run0019.csv
# data/normal/1000genome-20200826T065300Z-run0047.csv
# data/normal/1000genome-20200518T045356Z-run0005.csv
# data/normal/1000genome-20200826T065300Z-run0013.csv
# data/normal/1000genome-20210109T082603Z-run0001.csv
# data/normal/1000genome-20200616T174351Z-run0036.csv
# data/normal/1000genome-20200518T045356Z-run0006.csv
# data/normal/1000genome-20200616T174351Z-run0015.csv
# data/normal/1000genome-20200518T045356Z-run0050.csv
# data/normal/1000genome-20210109T082603Z-run0044.csv
# data/normal/1000genome-20200518T045356Z-run0003.csv
# data/normal/1000genome-20200518T045356Z-run0040.csv
# data/normal/1000genome-20200616T174351Z-run0029.csv
# data/normal/1000genome-20210109T082603Z-run0016.csv
# data/normal/1000genome-20200826T065300Z-run0030.csv
# data/normal/1000genome-20210109T082603Z-run0045.csv
# data/normal/1000genome-20210109T082603Z-run0025.csv
# data/normal/1000genome-20200826T065300Z-run0016.csv
# data/normal/1000genome-20210109T082603Z-run0050.csv
# data/normal/1000genome-20200518T045356Z-run0047.csv
# data/normal/1000genome-20200616T174351Z-run0006.csv
# data/normal/1000genome-20210109T082603Z-run0007.csv
# data/normal/1000genome-20200616T174351Z-run0016.csv
# data/normal/1000genome-20200616T174351Z-run0008.csv
# data/normal/1000genome-20200616T174351Z-run0048.csv
# data/normal/1000genome-20200518T045356Z-run0028.csv
# data/normal/1000genome-20200826T065300Z-run0042.csv
# data/normal/1000genome-20200826T065300Z-run0034.csv
# data/normal/1000genome-20200518T045356Z-run0038.csv
# data/normal/1000genome-20200616T174351Z-run0011.csv
# data/normal/1000genome-20200616T174351Z-run0050.csv
# data/normal/1000genome-20210109T082603Z-run0015.csv
# data/normal/1000genome-20200518T045356Z-run0019.csv
# data/normal/1000genome-20200518T045356Z-run0035.csv
# data/normal/1000genome-20210109T082603Z-run0004.csv
# data/normal/1000genome-20200616T174351Z-run0027.csv
# data/normal/1000genome-20200616T174351Z-run0037.csv
# data/normal/1000genome-20200826T065300Z-run0038.csv
# data/normal/1000genome-20200616T174351Z-run0047.csv
# data/normal/1000genome-20210109T082603Z-run0024.csv
# data/normal/1000genome-20200826T065300Z-run0026.csv
# data/normal/1000genome-20210109T082603Z-run0034.csv
# data/normal/1000genome-20200616T174351Z-run0026.csv
# data/normal/1000genome-20200826T065300Z-run0003.csv
# data/normal/1000genome-20200826T065300Z-run0001.csv
# data/normal/1000genome-20210109T082603Z-run0021.csv
# data/normal/1000genome-20200826T065300Z-run0045.csv
# data/normal/1000genome-20210109T082603Z-run0022.csv
# data/normal/1000genome-20200616T174351Z-run0033.csv
# data/normal/1000genome-20210109T082603Z-run0038.csv
# data/normal/1000genome-20200616T174351Z-run0007.csv
# data/normal/1000genome-20200826T065300Z-run0044.csv
# data/normal/1000genome-20200518T045356Z-run0017.csv
# data/normal/1000genome-20200518T045356Z-run0045.csv
# data/normal/1000genome-20200518T045356Z-run0036.csv
# data/normal/1000genome-20200518T045356Z-run0009.csv
# data/normal/1000genome-20210109T082603Z-run0017.csv
# data/normal/1000genome-20200826T065300Z-run0006.csv
# data/normal/1000genome-20210109T082603Z-run0005.csv
# data/normal/1000genome-20210109T082603Z-run0006.csv
# data/normal/1000genome-20210109T082603Z-run0032.csv
# data/normal/1000genome-20210109T082603Z-run0010.csv
# data/normal/1000genome-20200826T065300Z-run0033.csv
# data/normal/1000genome-20200826T065300Z-run0011.csv
# data/normal/1000genome-20200518T045356Z-run0002.csv
# data/normal/1000genome-20210109T082603Z-run0037.csv
# data/normal/1000genome-20210109T082603Z-run0036.csv
# data/normal/1000genome-20200826T065300Z-run0037.csv
# data/normal/1000genome-20200826T065300Z-run0020.csv
# data/normal/1000genome-20200518T045356Z-run0016.csv
# data/normal/1000genome-20210109T082603Z-run0039.csv
# data/normal/1000genome-20200616T174351Z-run0030.csv
# data/normal/1000genome-20200518T045356Z-run0011.csv
# data/normal/1000genome-20210109T082603Z-run0041.csv
# data/normal/1000genome-20200616T174351Z-run0009.csv
# data/normal/1000genome-20200616T174351Z-run0043.csv
# data/normal/1000genome-20200616T174351Z-run0005.csv
# data/normal/1000genome-20200826T065300Z-run0017.csv
# data/normal/1000genome-20200518T045356Z-run0013.csv
# data/normal/1000genome-20200616T174351Z-run0020.csv
# data/normal/1000genome-20200616T174351Z-run0019.csv
# data/normal/1000genome-20200616T174351Z-run0038.csv
# data/normal/1000genome-20200518T045356Z-run0046.csv
# data/normal/1000genome-20210109T082603Z-run0040.csv
# data/normal/1000genome-20200826T065300Z-run0012.csv
# data/normal/1000genome-20200518T045356Z-run0007.csv
# data/normal/1000genome-20200518T045356Z-run0034.csv
# data/normal/1000genome-20210109T082603Z-run0043.csv
# data/normal/1000genome-20200826T065300Z-run0048.csv
# data/normal/1000genome-20200826T065300Z-run0014.csv
# data/normal/1000genome-20200518T045356Z-run0025.csv
# data/normal/1000genome-20200826T065300Z-run0039.csv
# data/normal/1000genome-20210109T082603Z-run0029.csv
# data/normal/1000genome-20200826T065300Z-run0031.csv
# data/normal/1000genome-20200826T065300Z-run0035.csv
# data/normal/1000genome-20210109T082603Z-run0019.csv
# data/normal/1000genome-20200518T045356Z-run0042.csv
# data/normal/1000genome-20200518T045356Z-run0018.csv
# data/normal/1000genome-20200826T065300Z-run0029.csv
# data/normal/1000genome-20200616T174351Z-run0017.csv
# data/normal/1000genome-20200616T174351Z-run0042.csv
# data/normal/1000genome-20200616T174351Z-run0010.csv
# data/normal/1000genome-20210109T082603Z-run0012.csv
# data/normal/1000genome-20200826T065300Z-run0021.csv
# data/normal/1000genome-20210109T082603Z-run0014.csv
# data/normal/1000genome-20200616T174351Z-run0023.csv
# data/normal/1000genome-20200616T174351Z-run0025.csv
# data/normal/1000genome-20200616T174351Z-run0045.csv
# data/normal/1000genome-20200826T065300Z-run0025.csv
# data/normal/1000genome-20200826T065300Z-run0024.csv
# data/normal/1000genome-20200616T174351Z-run0028.csv
# data/normal/1000genome-20200616T174351Z-run0031.csv
# data/normal/1000genome-20200826T065300Z-run0040.csv
# data/normal/1000genome-20210109T082603Z-run0035.csv
# data/normal/1000genome-20200826T065300Z-run0023.csv
# data/normal/1000genome-20200826T065300Z-run0018.csv
# data/normal/1000genome-20200518T045356Z-run0020.csv
# data/normal/1000genome-20200826T065300Z-run0015.csv
# data/normal/1000genome-20200826T065300Z-run0036.csv
# data/normal/1000genome-20210109T082603Z-run0049.csv
# data/normal/1000genome-20210109T082603Z-run0048.csv
# data/normal/1000genome-20200518T045356Z-run0039.csv
# data/normal/1000genome-20210109T082603Z-run0018.csv
# data/normal/1000genome-20200616T174351Z-run0004.csv
# data/normal/1000genome-20210109T082603Z-run0011.csv
# data/normal/1000genome-20200518T045356Z-run0032.csv
# data/normal/1000genome-20200826T065300Z-run0043.csv
# data/normal/1000genome-20210109T082603Z-run0026.csv
# data/normal/1000genome-20200518T045356Z-run0021.csv
# data/normal/1000genome-20200826T065300Z-run0002.csv
# data/normal/1000genome-20200518T045356Z-run0023.csv
# data/normal/1000genome-20210109T082603Z-run0020.csv
# data/normal/1000genome-20200826T065300Z-run0022.csv
# data/normal/1000genome-20200518T045356Z-run0041.csv
# data/normal/1000genome-20210109T082603Z-run0027.csv
# data/normal/1000genome-20200616T174351Z-run0001.csv
# data/normal/1000genome-20200826T065300Z-run0007.csv
# data/normal/1000genome-20200616T174351Z-run0040.csv
# data/normal/1000genome-20200616T174351Z-run0034.csv
# data/normal/1000genome-20200518T045356Z-run0044.csv
# data/normal/1000genome-20200826T065300Z-run0009.csv
# data/normal/1000genome-20210109T082603Z-run0042.csv
# data/normal/1000genome-20200518T045356Z-run0022.csv
# data/normal/1000genome-20200616T174351Z-run0003.csv
# data/normal/1000genome-20200616T174351Z-run0024.csv
# data/normal/1000genome-20210109T082603Z-run0002.csv
# data/normal/1000genome-20200826T065300Z-run0004.csv
# data/normal/1000genome-20200518T045356Z-run0027.csv
# data/normal/1000genome-20200826T065300Z-run0049.csv
# data/normal/1000genome-20200616T174351Z-run0041.csv
# data/normal/1000genome-20200826T065300Z-run0005.csv
# data/normal/1000genome-20200616T174351Z-run0014.csv
# data/normal/1000genome-20210109T082603Z-run0023.csv
# data/normal/1000genome-20200616T174351Z-run0013.csv
# data/normal/1000genome-20210109T082603Z-run0008.csv
# data/normal/1000genome-20210109T082603Z-run0030.csv
# data/normal/1000genome-20200826T065300Z-run0041.csv
# data/normal/1000genome-20200518T045356Z-run0001.csv
# data/normal/1000genome-20210109T082603Z-run0031.csv
# data/normal/1000genome-20200518T045356Z-run0010.csv
# data/normal/1000genome-20200518T045356Z-run0029.csv
# data/normal/1000genome-20200826T065300Z-run0046.csv
# data/normal/1000genome-20200826T065300Z-run0027.csv
# data/normal/1000genome-20210109T082603Z-run0028.csv
# data/normal/1000genome-20200518T045356Z-run0015.csv
# data/normal/1000genome-20200518T045356Z-run0033.csv
# data/normal/1000genome-20210109T082603Z-run0009.csv
# data/normal/1000genome-20200616T174351Z-run0022.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [2], in <cell line: 12>()
#      28 else:
#      29     new_l = l
# ---> 31 job_features = features[features.index.str.startswith(new_l)][['type', 'is_clustered', 'ready',
#      32                        'submit', 'execute_start', 'execute_end', 'post_script_start',
#      33                        'post_script_end', 'wms_delay', 'pre_script_delay', 'queue_delay',
#      34                        'runtime', 'post_script_delay', 'stage_in_delay', 'stage_out_delay',
#      35                        'stage_in_bytes', 'stage_out_bytes', 'kickstart_user', 'kickstart_site',
#      36                        'kickstart_hostname', 'kickstart_transformations', 'kickstart_executables',
#      37                        'kickstart_executables_argv', 'kickstart_executables_cpu_time', 'kickstart_status',
#      38                        'kickstart_executables_exitcode']].values.tolist()[0]
#      41 if job_features[0]=='auxiliary':
#      42     job_features[0]= 0
#
# File ~/python_envs/graph_env/lib/python3.10/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/python_envs/graph_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/python_envs/graph_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['is_clustered', 'stage_in_bytes', 'stage_out_bytes', 'kickstart_user', 'kickstart_site', 'kickstart_hostname', 'kickstart_transformations', 'kickstart_executables', 'kickstart_executables_argv', 'kickstart_executables_cpu_time', 'kickstart_status', 'kickstart_executables_exitcode'] not in index"

# %%
## Dumped into the pickle file.
import pickle
with open('graph.pkl','wb') as f:
    pickle.dump(graphs, f)

# %%
# Import the file.
import pickle
with open('graph.pkl','rb') as f:
    graphs= pickle.load(f)

# %%
import numpy as np
y_list = []
for gr in graphs:
    y_list.append(gr['y'])
print(min(y_list))
print(max(y_list))
print(np.unique(np.array(y_list), return_counts=True))
# Out:
# 0
# 3
# (array([0, 1, 2, 3]), array([171, 150, 273, 124]))

# %%
from torch_geometric.data import Data
import torch
datasets=[]
import numpy
for element in graphs:
    print(element['x'][0])
    gx = torch.tensor(numpy.array(element['x']) ) 
    ge =torch.tensor(numpy.array(element['edge_index']) ).T
    gy =torch.tensor(numpy.array(element['y']).reshape([-1]))
    # print(gx.shape, ge.shape, gy.shape)
    # print(gy)
    v_min, v_max = gx.min(), gx.max()
    new_min, new_max = 0, 1
    gx = (gx - v_min)/(v_max - v_min)*(new_max - new_min) + new_min
    # print(gx.min(), gx.max())
    datasets.append( Data(x=gx, edge_index=ge, y=gy) )
# Out:
# [0, 0, 1590188341.0, 1590188345.0, 1590188346.0, 1590188350.0, 1590188350.0, 1590188355.0, 4.0, -1, 1.0, 4.0, 5.0, -1, -1, -1, -1, 'panorama', 'local', 'master', 'pegasus::dirmanager', '/home/panorama/pegasus-4.9.3panorama/bin/pegasus-transfer', -1, 0.3, 0, 0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 5>()
#       5 for element in graphs:
#       6     print(element['x'][0])
# ----> 7     gx = torch.tensor(numpy.array(element['x']) )
#       8     ge =torch.tensor(numpy.array(element['edge_index']) ).T
#       9     gy =torch.tensor(numpy.array(element['y']).reshape([-1]))
#
# TypeError: can't convert np.ndarray of type numpy.str_. The only supported types are: float64, float32, float16, complex64, complex128, int64, int32, int16, int8, uint8, and bool.

# %%
import torch
from torch_geometric.datasets import TUDataset

dataset = datasets

# print()
# print(f'Dataset: {dataset}:')
print('====================')
print(f'Number of graphs: {len(dataset)}')
# print(f'Number of features: {dataset.num_features}')
# print(f'Number of classes: {dataset.num_classes}')
data = dataset[0]  # Get the first graph object.
print()
print(data)
print('=============================================================')
# Gather some statistics about the first graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')

# %%
torch.manual_seed(12345)
import random
random.seed(12345)
random.shuffle(datasets)
train_dataset = datasets[:1000]
test_dataset = datasets[1000:]

print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')

# %%
from torch_geometric.loader import DataLoader

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(14, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 4)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)
        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]
        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        return x

model = GCN(hidden_channels=64)
print(model)

# %%
# from IPython.display import Javascript
# display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 300})'''))

model = GCN(hidden_channels=64).float()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    for data in train_loader:  # Iterate in batches over the training dataset.
        out = model(data.x.float(), data.edge_index, data.batch)  # Perform a single forward pass.
        loss = criterion(out, data.y)  # Compute the loss.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        optimizer.zero_grad()  # Clear gradients.

def test(loader):
    model.eval()
    correct = 0
    for data in loader:  # Iterate in batches over the training/test dataset.
        out = model(data.x.float(), data.edge_index, data.batch)  
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        correct += int((pred == data.y).sum())  # Check against ground-truth labels.
    return correct / len(loader.dataset)  # Derive ratio of correct predictions.
import torch.optim.lr_scheduler as lrs
scheduler = lrs.ExponentialLR(optimizer, gamma=0.9)
for epoch in range(1, 1000):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    if epoch%50 ==0:
        scheduler.step()
        print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
