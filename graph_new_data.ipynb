# %% [markdown]
# ## Genome

# %%
def genome_graphs(total_columns, classes):
    print("genome")
    import json
    import glob
    import os
    import pandas as pd
    import numpy as np
    with open("adjacency_list_dags/1000genome.json", "r") as f:
        adjacency_list = json.load(f)
    counter = 0
    edge_index = []
    lookup = {}
    for l in adjacency_list:
        lookup[l] = counter
        counter+=1
    for l in adjacency_list:
        for e in adjacency_list[l]:
            edge_index.append([lookup[l], lookup[e]])
    import math
    count =0
    graphs=[]
    for d in os.listdir("data"):
        print(d)
        for f in glob.glob(os.path.join("data", d, "1000genome*")):
            if f in ["data/cpu_3/1000genome-20200613T072602Z-run0011.csv",
                    "data/hdd_100/1000genome-20200901T234910Z-run0048.csv",
                    "data/hdd_100/1000genome-20200901T234910Z-run0049.csv",
                    "data/loss_1/1000genome-20200520T215721Z-run0014.csv",
                    "data/norma/1000genome-20200616T174351Z-run0022.csv", 
                    "data/normal/1000genome-20200616T174351Z-run0022.csv"]: continue
            graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
            features = pd.read_csv(f, index_col=[0])
            for l in lookup:
                if l.startswith("create_dir_") or l.startswith("cleanup_"):
                    new_l = l.split("-")[0]
                else:
                    new_l = l
                job_features = features[features.index.str.startswith(new_l)][total_columns].values.tolist()[0]
                job_features = [-1 if x != x else x for x in job_features]   
                minim = min(job_features[2:8])
                job_features[2:8] = [ j-minim for j in job_features[2:8]]
                graph['x'].insert(lookup[l], job_features)
            graphs.append(graph)
    return graphs

# %% [markdown]
# ## Nowcluster 16

# %%
def nowcluster_16(total_columns, classes):
    print("casa_nowcast_clustering_16")
    import json
    import glob
    import os
    import pandas as pd
    import numpy as np
    graphs = []
    counter = 0
    edge_index = []
    lookup = {}
    with open("adjacency_list_dags/casa_nowcast_clustering_16.json", "r") as f:
        adjacency_list = json.load(f)
    for l in adjacency_list:
        lookup[l] = counter
        counter+=1
    for l in adjacency_list:
        for e in adjacency_list[l]:
            edge_index.append([lookup[l], lookup[e]])               
    for d in os.listdir("data"):
        print(d)
        for f in glob.glob(os.path.join("data", d, "nowcast-clustering-16*")):
            graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
            features = pd.read_csv(f, index_col=[0])
            features= features.replace('', -1, regex=True)
            # time_list
            for l in lookup:
                if l.startswith("create_dir_") or l.startswith("cleanup_"):
                    new_l = l.split("-")[0]
                else:
                    new_l = l
                job_features = features[features.index.str.startswith(new_l)][total_columns].values.tolist()[0]
                job_features = [-1 if x != x else x for x in job_features]   
                minim = min(job_features[2:8])
                job_features[2:8] = [ j-minim for j in job_features[2:8]]
                graph['x'].insert(lookup[l], job_features)     
            graphs.append(graph)
    return graphs

# %% [markdown]
# ## Nowcast clustering 8

# %%
def nowcluster_8(total_columns, classes):
    import json
    import glob
    import os
    import pandas as pd
    import numpy as np
    print("casa_nowcast_clustering_8")
    counter = 0
    edge_index = []
    lookup = {}
    with open("adjacency_list_dags/casa_nowcast_clustering_8.json", "r") as f:
        adjacency_list = json.load(f)
    for l in adjacency_list:
        lookup[l] = counter
        counter+=1
    for l in adjacency_list:
        for e in adjacency_list[l]:
            edge_index.append([lookup[l], lookup[e]])     
    for d in os.listdir("data"):
        print(d)
        for f in glob.glob(os.path.join("data", d, "nowcast-clustering-8*")):
            graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
            features = pd.read_csv(f, index_col=[0])
            features= features.replace('', -1, regex=True)
            # time_list
            for l in lookup:
                if l.startswith("create_dir_") or l.startswith("cleanup_"):
                    new_l = l.split("-")[0]
                else:
                    new_l = l
                job_features = features[features.index.str.startswith(new_l)][total_columns].values.tolist()[0]
                job_features = [-1 if x != x else x for x in job_features]   
                minim = min(job_features[2:8])
                job_features[2:8] = [ j-minim for j in job_features[2:8]]
                graph['x'].insert(lookup[l], job_features)
            graphs.append(graph)
    return graphs

# %% [markdown]
# ## WIND Clustering

# %%
def wind_clustering(total_columns, classes):
    graphs=[]
    print("casa_wind_clustering")
    counter = 0
    edge_index = []
    lookup = {}
    with open("adjacency_list_dags/casa_wind_clustering.json", "r") as f:
        adjacency_list = json.load(f)
    for l in adjacency_list:
        lookup[l] = counter
        counter+=1
    for l in adjacency_list:
        for e in adjacency_list[l]:
            edge_index.append([lookup[l], lookup[e]])   
    for d in os.listdir("data"):
        print(d)
        for f in glob.glob(os.path.join("data", d, "wind-clustering-casa*")):
            graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
            features = pd.read_csv(f, index_col=[0])
            features= features.replace('', -1, regex=True)
            # print(features)
            # time_list
            for l in lookup:
                if l.startswith("create_dir_") or l.startswith("cleanup_"):
                    new_l = l.split("-")[0]
                else:
                    new_l = l
                job_features = features[features.index.str.startswith(new_l)][total_columns].values.tolist()[0]
                job_features = [-1 if x != x else x for x in job_features]   
                minim = min(job_features[2:8])
                job_features[2:8] = [ j-minim for j in job_features[2:8]]
                graph['x'].insert(lookup[l], job_features)
            graphs.append(graph)
    return graphs

# %% [markdown]
# ## Wind No Clustering

# %%
def wind_no_clustering(total_columns, classes):
    counter = 0
    edge_index = []
    lookup = {}
    print("casa_wind_no_clustering")
    with open("adjacency_list_dags/casa_wind_no_clustering.json", "r") as f:
        adjacency_list = json.load(f)
    for l in adjacency_list:
        lookup[l] = counter
        counter+=1
    for l in adjacency_list:
        for e in adjacency_list[l]:
            edge_index.append([lookup[l], lookup[e]])     
    for d in os.listdir("data"):
        print(d)
        for f in glob.glob(os.path.join("data", d, "wind-noclustering-casa*")):
            if "-20200817T052029Z-" in f: continue
            graph = {"y": classes[d.split("_")[0]], "edge_index": edge_index, "x":[]}
            features = pd.read_csv(f, index_col=[0])
            features= features.replace('', -1, regex=True)
            # time_list
            for l in lookup:
                if l.startswith("create_dir_") or l.startswith("cleanup_"):
                    new_l = l.split("-")[0]
                else:
                    new_l = l
                job_features = features[features.index.str.startswith(new_l)][total_columns].values.tolist()[0]
                job_features = [-1 if x != x else x for x in job_features]   
                minim = min(job_features[2:8])
                job_features[2:8] = [ j-minim for j in job_features[2:8]]
                graph['x'].insert(lookup[l], job_features)
            graphs.append(graph) 
    return graphs

# %%
## The overall code for the work

# %%
import numpy as np
import pandas as pd
# Get all
import json
import glob
import os
import pandas as pd
import numpy as np
classes = {"normal": 0}
counter = 1
for d in os.listdir("data"):
    d = d.split("_")[0]
    if d in classes: continue
    classes[d] = counter
    counter += 1
columns_full= ['type', 'is_clustered', 'ready',
    'submit', 'execute_start', 'execute_end', 'post_script_start',
    'post_script_end', 'wms_delay', 'pre_script_delay', 'queue_delay',
    'runtime', 'post_script_delay', 'stage_in_delay', 'stage_out_delay',
    'stage_in_bytes', 'stage_out_bytes', 'kickstart_user', 'kickstart_site', 
    'kickstart_hostname', 'kickstart_transformations', 'kickstart_executables',
    'kickstart_executables_argv', 'kickstart_executables_cpu_time', 'kickstart_status',
    'kickstart_executables_exitcode']

# %%
Tota_data=[]
#######################################
## Get genome
graphs = genome_graphs(total_columns = columns_full, classes=classes)
print(len(graphs))
## Dumped into the pickle file.
import pickle
with open('graph_genome_preprocessed.pkl','wb') as f:
    pickle.dump(graphs, f)
Tota_data.extend(graphs)
print(len(Tota_data))

#######################################
## Get nowcluster 16
graphs = nowcluster_16(total_columns = columns_full, classes=classes)
print(len(graphs))
## Dumped into the pickle file.
import pickle
with open('graph_nowcluster_16_preprocessed.pkl','wb') as f:
    pickle.dump(graphs, f)
print(len(Tota_data))
Tota_data.extend(graphs)

#######################################
## Get nowcluster 8
graphs = nowcluster_8(total_columns = columns_full, classes=classes)
print(len(graphs))
## Dumped into the pickle file.
import pickle
with open('graph_nowcluster_8_preprocessed.pkl','wb') as f:
    pickle.dump(graphs, f)
print(len(Tota_data))
Tota_data.extend(graphs)

#######################################
## Get wind no clustering
graphs =  wind_no_clustering(total_columns = columns_full, classes=classes)
print(len(graphs))
## Dumped into the pickle file.
import pickle
with open('graph_wind_no_clust_preprocessed.pkl','wb') as f:
    pickle.dump(graphs, f)
print(len(Tota_data))
Tota_data.extend(graphs)

#######################################
## Get wind clustering
graphs =  wind_clustering(total_columns = columns_full, classes=classes)
print(len(graphs))
## Dumped into the pickle file.
import pickle
with open('graph_wind_clust_preprocessed.pkl','wb') as f:
    pickle.dump(graphs, f)
Tota_data.extend(graphs)
print(len(Tota_data))
# Out:
# genome
# cpu_2
# cpu_3
# hdd_100
# hdd_50
# hdd_60
# hdd_70
# hdd_80
# hdd_90
# loss_0.1
# loss_0.5
# loss_1
# loss_3
# loss_5
# normal
# 1270
# 1270
# casa_nowcast_clustering_16
# cpu_2
# cpu_3
# hdd_100
# hdd_50
# hdd_60
# hdd_70
# hdd_80
# hdd_90
# loss_0.1
# loss_0.5
# loss_1
# loss_3
# loss_5
# normal
# 1230
# 1270
# casa_nowcast_clustering_8
# cpu_2
# cpu_3
# hdd_100
# hdd_50
# hdd_60
# hdd_70
# hdd_80
# hdd_90
# loss_0.1
# loss_0.5
# loss_1
# loss_3
# loss_5
# normal
# 2460
# 2500
# casa_wind_no_clustering
# cpu_2
# cpu_3
# hdd_100
# hdd_50
# hdd_60
# hdd_70
# hdd_80
# hdd_90
# loss_0.1
# loss_0.5
# loss_1
# loss_3
# loss_5
# normal
# 3649
# 4960
# casa_wind_clustering
# cpu_2
# cpu_3
# hdd_100
# hdd_50
# hdd_60
# hdd_70
# hdd_80
# hdd_90
# loss_0.1
# loss_0.5
# loss_1
# loss_3
# loss_5
# normal
# 1230
# 9839

# %%
import pickle
with open('graph_all_data_preprocessed.pkl','wb') as f:
    pickle.dump(Tota_data, f)

# %% [markdown]
# ## The  main code to run and train the model.

# %%
import torch 
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv,  SAGEConv
from torch_geometric.nn import global_mean_pool
class GCN(torch.nn.Module):
    def __init__(self, hidden_channels, input_chan):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = SAGEConv(input_chan, hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, hidden_channels)
        self.lin1 = Linear(hidden_channels, hidden_channels)
        self.lin2 = Linear(hidden_channels, 4)
        

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)
        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]
        # 3. Apply a final classifier
        x = self.lin1(x)
        x = x.relu()
        x = F.dropout(x, p=0.1, training=self.training)
        x = self.lin2(x)
        return x
    
def convert_tensors(graphs):
    import numpy as np
    y_list = []
    for gr in graphs:
        y_list.append(gr['y'])
    import torch
    from torch_geometric.data import Data
    datasets=[]
    import numpy
    from sklearn.preprocessing import StandardScaler
    scaler =  StandardScaler()
    for element in graphs:
        gx = torch.from_numpy(element['x'] )
        ge =torch.tensor(numpy.array(element['edge_index']) ).T
        gy =torch.tensor(numpy.array(element['y']).reshape([-1]))
        if gx.shape[0] >0 :
            datasets.append( Data(x=gx, edge_index=ge, y=gy) )
    
    import torch
    from torch_geometric.datasets import TUDataset
    print('====================')
    print(f'Number of graphs: {len(datasets)}')
    # print(f'Number of features: {dataset.num_features}')
    # print(f'Number of classes: {dataset.num_classes}')
    data = datasets[0]  # Get the first graph object.
    print()
    print(data)
    print('=============================================================')
    # Gather some statistics about the first graph.
    print(f'Number of nodes: {data.num_nodes}')
    print(f'Number of edges: {data.num_edges}')
    print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
    print(f'Has isolated nodes: {data.has_isolated_nodes()}')
    print(f'Has self-loops: {data.has_self_loops()}')
    print(f'Is undirected: {data.is_undirected()}')
    return datasets

def convert_dataloader(datasets,  batch_size):
    import torch
    import random
    torch.manual_seed(12345)
    random.seed(12345)
    random.shuffle(datasets)
    
    train_dataset = datasets[: int(len(datasets)*0.80) ]
    test_dataset = datasets[int(len(datasets)*0.80):]
    print(f'Number of training graphs: {len(train_dataset)}')
    print(f'Number of test graphs: {len(test_dataset)}')
    
    from torch_geometric.loader import DataLoader
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
    return train_loader, test_loader

def train(model, loader, criterion):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.train()
    for data in loader:  # Iterate in batches over the training dataset.
        out = model(data.x.float().to(device), data.edge_index.to(device), data.batch.to(device))  # Perform a single forward pass.
        loss = criterion(out, data.y.to(device))  # Compute the loss.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        optimizer.zero_grad()  # Clear gradients.

def test(model, loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    correct = 0            
    for data in loader:  # Iterate in batches over the training/test dataset.
        out = model(data.x.float().to(device), data.edge_index.to(device), data.batch.to(device))  
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        correct += int((pred == data.y.to(device)).sum())  # Check against ground-truth labels.
    return correct / len(loader.dataset)  # Derive ratio of correct predictions.

# %%
import torch
def process_data(graphs, drop_columns):## Now, preprocess that for the columns I specify
    number_data=[]
    flat_list = [item  for sublist in graphs for item in sublist['x']]
    number_data = [len(sublist['x']) for sublist in graphs]
    
    df = pd.DataFrame(flat_list, columns=columns_full)
    df = df.drop(drop_columns, axis=1)
    
    from sklearn.preprocessing import LabelEncoder
    labelencoder = LabelEncoder()
    for string in ['type', 'kickstart_user', 'kickstart_site',\
                   'kickstart_hostname', 'kickstart_transformations']:
            df[string] =labelencoder.fit_transform(df[string].astype(str))
    
    array = df.to_numpy().astype('float64')
    prev = 0
    nexts= 0
    new_min, new_max = 0, 1
    gx = array
    v_min, v_max = gx.min(), gx.max()
    gx = (gx - v_min)/(v_max - v_min)*(new_max - new_min) + new_min
    print(gx.min(), gx.max())
    from sklearn.preprocessing import StandardScaler
    scaler =  StandardScaler()
    scaler.fit_transform(gx)
    for i in range(len(graphs)):
        nexts+=number_data[i]
        graphs[i]['x']= array[prev:nexts,:]
        prev+=number_data[i]
    print(len(graphs))
    return graphs

# %% [markdown]
# ## Test Genome

# %%
import pandas as pd
## Dumped into the pickle file.
import pickle
with open('graph_genome_preprocessed.pkl','rb') as f:
    graphs = pickle.load(f)
drop_columns= [ 'stage_in_bytes', 'stage_out_bytes', 'kickstart_executables','kickstart_executables_argv']
graphs = process_data(graphs, drop_columns)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
datasets= convert_tensors(graphs)
train_loader, test_loader = convert_dataloader(datasets, batch_size=32)
model = GCN(hidden_channels=32, input_chan = 22).float().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()
import torch.optim.lr_scheduler as lrs
for epoch in range(1, 2000):
    train(model, train_loader, criterion)
    train_acc = test(model, train_loader)
    test_acc = test(model, test_loader)
    if epoch%100==0:
        print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
        flag='genome'   
        torch.save(model.state_dict(), 'model_'+flag+'_')
# Out:
# 0.0 1.0
# 1270
# ====================
# Number of graphs: 1270
#
# Data(x=[57, 22], edge_index=[2, 129], y=[1])
# =============================================================
# Number of nodes: 57
# Number of edges: 129
# Average node degree: 2.26
# Has isolated nodes: True
# Has self-loops: False
# Is undirected: False
# Number of training graphs: 1016
# Number of test graphs: 254
# Epoch: 100, Train Acc: 0.9213, Test Acc: 0.9016
# Epoch: 200, Train Acc: 0.8730, Test Acc: 0.8504
# Epoch: 300, Train Acc: 0.9104, Test Acc: 0.8898
# Epoch: 400, Train Acc: 0.9508, Test Acc: 0.9173
# Epoch: 500, Train Acc: 0.9508, Test Acc: 0.9252
# Epoch: 600, Train Acc: 0.9518, Test Acc: 0.9213
# Epoch: 700, Train Acc: 0.9528, Test Acc: 0.9173
# Epoch: 800, Train Acc: 0.9498, Test Acc: 0.9055
# Epoch: 900, Train Acc: 0.9577, Test Acc: 0.9213
# Epoch: 1000, Train Acc: 0.9606, Test Acc: 0.9094
# Epoch: 1100, Train Acc: 0.9596, Test Acc: 0.9213
# Epoch: 1200, Train Acc: 0.9518, Test Acc: 0.9252
# Epoch: 1300, Train Acc: 0.9557, Test Acc: 0.9094
# Epoch: 1400, Train Acc: 0.9636, Test Acc: 0.9055
# Epoch: 1500, Train Acc: 0.9567, Test Acc: 0.9173
# Epoch: 1600, Train Acc: 0.9636, Test Acc: 0.9016
# Epoch: 1700, Train Acc: 0.9606, Test Acc: 0.9134
# Epoch: 1800, Train Acc: 0.9626, Test Acc: 0.9173
# Epoch: 1900, Train Acc: 0.9646, Test Acc: 0.9134

# %% [markdown]
# ## Test nowcluster 16

# %%
## Dumped into the pickle file.
import pickle
with open('graph_nowcluster_16_preprocessed.pkl','rb') as f:
    graphs = pickle.load(f)
drop_columns= [ 'stage_in_bytes', 'stage_out_bytes', 'kickstart_executables','kickstart_executables_argv']
graphs = process_data(graphs, drop_columns)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
datasets= convert_tensors(graphs)
train_loader, test_loader = convert_dataloader(datasets, batch_size=32)
model = GCN(hidden_channels=32, input_chan = 22).float().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

import torch.optim.lr_scheduler as lrs
for epoch in range(1, 2000):
    train(model, train_loader, criterion)
    train_acc = test(model, train_loader)
    test_acc = test(model, test_loader)
    if epoch%100==0:
        flag='nowcluster_16'   
        torch.save(model.state_dict(), 'model_'+flag+'_')  
        print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# 0.0 1.0
# 1230
# ====================
# Number of graphs: 1230
#
# Data(x=[9, 22], edge_index=[2, 12], y=[1])
# =============================================================
# Number of nodes: 9
# Number of edges: 12
# Average node degree: 1.33
# Has isolated nodes: True
# Has self-loops: False
# Is undirected: False
# Number of training graphs: 984
# Number of test graphs: 246
# Epoch: 100, Train Acc: 0.7033, Test Acc: 0.7114
# Epoch: 200, Train Acc: 0.8293, Test Acc: 0.8211
# Epoch: 300, Train Acc: 0.8303, Test Acc: 0.7886
# Epoch: 400, Train Acc: 0.8039, Test Acc: 0.8211
# Epoch: 500, Train Acc: 0.8374, Test Acc: 0.8049
# Epoch: 600, Train Acc: 0.9004, Test Acc: 0.8211
# Epoch: 700, Train Acc: 0.8811, Test Acc: 0.8171
# Epoch: 800, Train Acc: 0.9289, Test Acc: 0.8537
# Epoch: 900, Train Acc: 0.8953, Test Acc: 0.8455
# Epoch: 1000, Train Acc: 0.9065, Test Acc: 0.8211
# Epoch: 1100, Train Acc: 0.9339, Test Acc: 0.8333
# Epoch: 1200, Train Acc: 0.9268, Test Acc: 0.8374
# Epoch: 1300, Train Acc: 0.9278, Test Acc: 0.8211
# Epoch: 1400, Train Acc: 0.9604, Test Acc: 0.8455
# Epoch: 1500, Train Acc: 0.9553, Test Acc: 0.8211
# Epoch: 1600, Train Acc: 0.9644, Test Acc: 0.8415
# Epoch: 1700, Train Acc: 0.9685, Test Acc: 0.8293
# Epoch: 1800, Train Acc: 0.9482, Test Acc: 0.8171
# Epoch: 1900, Train Acc: 0.9421, Test Acc: 0.8171

# %%
## Dumped into the pickle file.
import pickle
with open('graph_nowcluster_8_preprocessed.pkl','rb') as f:
    graphs = pickle.load(f)
drop_columns= [ 'stage_in_bytes', 'stage_out_bytes', 'kickstart_executables','kickstart_executables_argv']
graphs = process_data(graphs, drop_columns)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
datasets= convert_tensors(graphs)
train_loader, test_loader = convert_dataloader(datasets, batch_size=32)
model = GCN(hidden_channels=32, input_chan = 22).float().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

import torch.optim.lr_scheduler as lrs
for epoch in range(1, 2000):
    train(model, train_loader, criterion)
    train_acc = test(model, train_loader)
    test_acc = test(model, test_loader)
    if epoch%100==0:
        flag='nowcluster_8'   
        torch.save(model.state_dict(), 'model_'+flag+'_')  
        print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# 0.0 1.0
# 2460
# ====================
# Number of graphs: 2460
#
# Data(x=[9, 22], edge_index=[2, 12], y=[1])
# =============================================================
# Number of nodes: 9
# Number of edges: 12
# Average node degree: 1.33
# Has isolated nodes: True
# Has self-loops: False
# Is undirected: False
# Number of training graphs: 1968
# Number of test graphs: 492
# Epoch: 100, Train Acc: 0.7683, Test Acc: 0.7602
# Epoch: 200, Train Acc: 0.8674, Test Acc: 0.8354
# Epoch: 300, Train Acc: 0.8704, Test Acc: 0.8537
# Epoch: 400, Train Acc: 0.9050, Test Acc: 0.8577
# Epoch: 500, Train Acc: 0.9035, Test Acc: 0.8537
# Epoch: 600, Train Acc: 0.9146, Test Acc: 0.8415
# Epoch: 700, Train Acc: 0.9319, Test Acc: 0.8598
# Epoch: 800, Train Acc: 0.9278, Test Acc: 0.8374
# Epoch: 900, Train Acc: 0.9304, Test Acc: 0.8496
# Epoch: 1000, Train Acc: 0.9334, Test Acc: 0.8537
# Epoch: 1100, Train Acc: 0.9634, Test Acc: 0.8679
# Epoch: 1200, Train Acc: 0.9411, Test Acc: 0.8699
# Epoch: 1300, Train Acc: 0.9588, Test Acc: 0.8740
# Epoch: 1400, Train Acc: 0.9472, Test Acc: 0.8435
# Epoch: 1500, Train Acc: 0.9710, Test Acc: 0.8699
# Epoch: 1600, Train Acc: 0.9522, Test Acc: 0.8679
# Epoch: 1700, Train Acc: 0.9812, Test Acc: 0.8598
# Epoch: 1800, Train Acc: 0.9614, Test Acc: 0.8354
# Epoch: 1900, Train Acc: 0.9741, Test Acc: 0.8537

# %%
## Dumped into the pickle file.
import pickle
with open('graph_wind_no_clust_preprocessed.pkl','rb') as f:
    graphs = pickle.load(f)
    
drop_columns= [ 'stage_in_bytes', 'stage_out_bytes', 'kickstart_executables','kickstart_executables_argv']
graphs = process_data(graphs, drop_columns)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
datasets= convert_tensors(graphs)
train_loader, test_loader = convert_dataloader(datasets, batch_size=32)
model = GCN(hidden_channels=32, input_chan = 22).float().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

import torch.optim.lr_scheduler as lrs
for epoch in range(1, 2000):
    train(model, train_loader, criterion)
    train_acc = test(model, train_loader)
    test_acc = test(model, test_loader)
    if epoch%100==0:
        flag='wind_no_cluster'   
        torch.save(model.state_dict(), 'model_'+flag+'_')  
        print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# 0.0 1.0
# 3649
# ====================
# Number of graphs: 3649
#
# Data(x=[9, 22], edge_index=[2, 12], y=[1])
# =============================================================
# Number of nodes: 9
# Number of edges: 12
# Average node degree: 1.33
# Has isolated nodes: True
# Has self-loops: False
# Is undirected: False
# Number of training graphs: 2919
# Number of test graphs: 730
# Epoch: 100, Train Acc: 0.7105, Test Acc: 0.6986
# Epoch: 200, Train Acc: 0.7924, Test Acc: 0.7822
# Epoch: 300, Train Acc: 0.8332, Test Acc: 0.8068
# Epoch: 400, Train Acc: 0.8434, Test Acc: 0.8260
# Epoch: 500, Train Acc: 0.8739, Test Acc: 0.8096
# Epoch: 600, Train Acc: 0.8804, Test Acc: 0.8260
# Epoch: 700, Train Acc: 0.8510, Test Acc: 0.8000
# Epoch: 800, Train Acc: 0.8924, Test Acc: 0.8110
# Epoch: 900, Train Acc: 0.8962, Test Acc: 0.8178
# Epoch: 1000, Train Acc: 0.9246, Test Acc: 0.8219
# Epoch: 1100, Train Acc: 0.8256, Test Acc: 0.7658
# Epoch: 1200, Train Acc: 0.8897, Test Acc: 0.8110
# Epoch: 1300, Train Acc: 0.9109, Test Acc: 0.8096
# Epoch: 1400, Train Acc: 0.9065, Test Acc: 0.8137
# Epoch: 1500, Train Acc: 0.9274, Test Acc: 0.8274
# Epoch: 1600, Train Acc: 0.9349, Test Acc: 0.8205
# Epoch: 1700, Train Acc: 0.9407, Test Acc: 0.8192
# Epoch: 1800, Train Acc: 0.9133, Test Acc: 0.8041
# Epoch: 1900, Train Acc: 0.9113, Test Acc: 0.8164

# %%
## Dumped into the pickle file.
import pickle
with open('graph_wind_clust_preprocessed.pkl','rb') as f:
    graphs = pickle.load(f)
drop_columns= [ 'stage_in_bytes', 'stage_out_bytes', 'kickstart_executables','kickstart_executables_argv']
graphs = process_data(graphs, drop_columns)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
datasets= convert_tensors(graphs)
train_loader, test_loader = convert_dataloader(datasets, batch_size=32)
model = GCN(hidden_channels=64, input_chan = 22).float().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

import torch.optim.lr_scheduler as lrs
for epoch in range(1, 5000):
    train(model, train_loader, criterion)
    train_acc = test(model, train_loader)
    test_acc = test(model, test_loader)
    if epoch%100==0:
        flag='wind_cluster'   
        torch.save(model.state_dict(), 'model_'+flag+'_')  
        print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# 0.0 1.0
# 1230
# ====================
# Number of graphs: 1230
#
# Data(x=[7, 22], edge_index=[2, 8], y=[1])
# =============================================================
# Number of nodes: 7
# Number of edges: 8
# Average node degree: 1.14
# Has isolated nodes: True
# Has self-loops: False
# Is undirected: False
# Number of training graphs: 984
# Number of test graphs: 246
# Epoch: 100, Train Acc: 0.5010, Test Acc: 0.4024
# Epoch: 200, Train Acc: 0.4990, Test Acc: 0.4065
# Epoch: 300, Train Acc: 0.5650, Test Acc: 0.4797
# Epoch: 400, Train Acc: 0.5915, Test Acc: 0.5285
# Epoch: 500, Train Acc: 0.6006, Test Acc: 0.5325
# Epoch: 600, Train Acc: 0.6402, Test Acc: 0.5813
# Epoch: 700, Train Acc: 0.6524, Test Acc: 0.5488
# Epoch: 800, Train Acc: 0.6565, Test Acc: 0.5691
# Epoch: 900, Train Acc: 0.6667, Test Acc: 0.5366
# Epoch: 1000, Train Acc: 0.6961, Test Acc: 0.5163
# Epoch: 1100, Train Acc: 0.7226, Test Acc: 0.5366
# Epoch: 1200, Train Acc: 0.7093, Test Acc: 0.5366
# Epoch: 1300, Train Acc: 0.6636, Test Acc: 0.4959
# Epoch: 1400, Train Acc: 0.7307, Test Acc: 0.5366
# Epoch: 1500, Train Acc: 0.7154, Test Acc: 0.4797
# Epoch: 1600, Train Acc: 0.7652, Test Acc: 0.5041
# Epoch: 1700, Train Acc: 0.7459, Test Acc: 0.5366
# Epoch: 1800, Train Acc: 0.7917, Test Acc: 0.5244
# Epoch: 1900, Train Acc: 0.7713, Test Acc: 0.5407

# %%
## Dumped into the pickle file.
import pickle
with open('graph_all_data_preprocessed.pkl','rb') as f:
    graphs = pickle.load(f)
drop_columns= [ 'stage_in_bytes', 'stage_out_bytes', 'kickstart_executables','kickstart_executables_argv']
graphs = process_data(graphs, drop_columns)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
datasets= convert_tensors(graphs)
train_loader, test_loader = convert_dataloader(datasets, batch_size=32)
model = GCN(hidden_channels=64, input_chan = 22).float().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

import torch.optim.lr_scheduler as lrs
for epoch in range(1, 10000):
    train(model, train_loader, criterion)
    train_acc = test(model, train_loader)
    test_acc = test(model, test_loader)
    if epoch%100==0:
        flag='all'   
        torch.save(model.state_dict(), 'model_'+flag+'_')  
        print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# 0.0 1.0
# 9839
# ====================
# Number of graphs: 9839
#
# Data(x=[57, 22], edge_index=[2, 129], y=[1])
# =============================================================
# Number of nodes: 57
# Number of edges: 129
# Average node degree: 2.26
# Has isolated nodes: True
# Has self-loops: False
# Is undirected: False
# Number of training graphs: 7871
# Number of test graphs: 1968
# Epoch: 100, Train Acc: 0.8226, Test Acc: 0.7927
# Epoch: 200, Train Acc: 0.8480, Test Acc: 0.8186
# Epoch: 300, Train Acc: 0.8827, Test Acc: 0.8343
# Epoch: 400, Train Acc: 0.9008, Test Acc: 0.8542
# Epoch: 500, Train Acc: 0.9125, Test Acc: 0.8603
# Epoch: 600, Train Acc: 0.9065, Test Acc: 0.8659
# Epoch: 700, Train Acc: 0.9178, Test Acc: 0.8623
# Epoch: 800, Train Acc: 0.9343, Test Acc: 0.8684
# Epoch: 900, Train Acc: 0.9240, Test Acc: 0.8592
# Epoch: 1000, Train Acc: 0.9452, Test Acc: 0.8811
# Epoch: 1100, Train Acc: 0.9347, Test Acc: 0.8689
# Epoch: 1200, Train Acc: 0.9503, Test Acc: 0.8786
# Epoch: 1300, Train Acc: 0.9512, Test Acc: 0.8801
# Epoch: 1400, Train Acc: 0.9520, Test Acc: 0.8872
# Epoch: 1500, Train Acc: 0.9282, Test Acc: 0.8603
# Epoch: 1600, Train Acc: 0.9455, Test Acc: 0.8694
# Epoch: 1700, Train Acc: 0.9510, Test Acc: 0.8806
# Epoch: 1800, Train Acc: 0.9522, Test Acc: 0.8852
# Epoch: 1900, Train Acc: 0.9538, Test Acc: 0.8877
# Epoch: 2000, Train Acc: 0.9618, Test Acc: 0.8902
# Epoch: 2100, Train Acc: 0.9554, Test Acc: 0.8780
# Epoch: 2200, Train Acc: 0.9230, Test Acc: 0.8735
# Epoch: 2300, Train Acc: 0.9397, Test Acc: 0.8643
# Epoch: 2400, Train Acc: 0.9619, Test Acc: 0.8887
# Epoch: 2500, Train Acc: 0.9626, Test Acc: 0.8877
# Epoch: 2600, Train Acc: 0.9629, Test Acc: 0.8872
# Epoch: 2700, Train Acc: 0.9597, Test Acc: 0.8872
# Epoch: 2800, Train Acc: 0.9615, Test Acc: 0.8765
# Epoch: 2900, Train Acc: 0.9308, Test Acc: 0.8552
# Epoch: 3000, Train Acc: 0.9690, Test Acc: 0.8836
# Epoch: 3100, Train Acc: 0.9656, Test Acc: 0.8908
